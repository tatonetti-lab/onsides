# %%
import numpy as np
import pandas as pd
import requests
from tqdm import tqdm
import ast, re
from time import sleep
from bs4 import BeautifulSoup
data_folder = '/content/drive/MyDrive/pop_pharmacogenomics/onsides_intl/uk_drug_label/'
external_data_folder = '/content/drive/MyDrive/pop_pharmacogenomics/onsides_intl/external_data/'
api = 'bbf40496-e20e-4f79-9636-b63d4a3deea7'
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Extract terms from text data here

# %%
text_df = pd.read_csv(data_folder+'data/drug_wp_data_raw.csv')
text_df['section_title'] = text_df['drug_text'].apply(lambda x: BeautifulSoup(x, 'html.parser').find('summary').text)
text_df['section_content'] = text_df.apply(lambda x: BeautifulSoup(x.drug_text, 'html.parser').text.replace(x.section_title, '').strip().lower(),
                                           axis = 1)
text_df.head(1)
# Out:
#    product_id                                          drug_text  \
# 0        1589  <details><summary data-evt="smpcSectionOpen" i...
#
#                                   section_title  \
# 0  4.4 Special warnings and precautions for use
#
#                                      section_content
# 0  prolonged and repeated applications are inadvi...

# %%
unique_text = text_df[['section_content']].drop_duplicates()
print(unique_text.shape[0])
# Out:
# 7607

# %%
#read in the meddra map file
f = '/content/drive/MyDrive/pop_pharmacogenomics/onsides_intl/'
meddra_df = pd.read_csv(f+'external_data/umls_meddra_en.csv')
meddra_df['STR'] = meddra_df.STR.apply(lambda x: x.lower())
meddra_df['len'] = meddra_df.STR.apply(lambda x: len(x))
print(meddra_df.shape[0])
meddra_df = meddra_df[(meddra_df['len'] >= 5)]
meddra_df = meddra_df[(meddra_df.TTY.isin(['PT', 'LLT']))]
print(meddra_df.shape[0])
meddra_dict = dict(zip(meddra_df.STR, meddra_df.SDUI))
meddra_names = meddra_df.STR.tolist()
meddra_df.head(1)
# Out:
# 116807
# 100897
#         CUI  LAT TS       LUI  STT       SUI ISPREF       AUI  SAUI  SCUI  \
# 0  C0000727  ENG  P  L0000727  VCW  S0584932      N  A0639292   NaN   NaN
#
#        SDUI  SAB TTY      CODE            STR  SRL SUPPRESS    CVF  len
# 0  10000647  MDR  PT  10000647  acute abdomen    3        N  256.0   13

# %%
app_data = []
for ade_text in tqdm(text_df.section_content.tolist()):
  if str(ade_text) != 'nan':
    ade_text = ade_text.lower()
    meddra_found_terms = []
    #iterate through list of meddra concepts, if found - add to list
    for concept_name in meddra_names:
      if ade_text.find(concept_name) == -1:
        continue
      else:
        i = ade_text.index(concept_name)
        meddra_found_terms.append([i, concept_name, meddra_dict[concept_name]])
    app_data.append([ade_text, meddra_found_terms])
# Out:
# 100%|██████████| 9532/9532 [1:01:18<00:00,  2.59it/s]

# %%
app_data_df = pd.DataFrame(app_data, columns = ['string', 'list'])
app_data_df = app_data_df.explode('list')
app_data_df['index'] = app_data_df['list'].apply(lambda x: x[0] if str(x) != 'nan' else None)
app_data_df['found_term'] = app_data_df['list'].apply(lambda x: x[1] if str(x) != 'nan' else None)
app_data_df['meddra_id'] = app_data_df['list'].apply(lambda x: x[2] if str(x) != 'nan' else None)
app_data_df = app_data_df.drop(['list'], axis = 1)
app_data_df.to_csv(data_folder+'data/drug_wp_text_matched_terms.csv', index=False)
app_data_df.head(1)

# %% [markdown]
# ### prepare onsides input

# %%
text_df = pd.read_csv(data_folder+'data/drug_wp_data_raw.csv')
text_df['section_title'] = text_df['drug_text'].apply(lambda x: BeautifulSoup(x, 'html.parser').find('summary').text)
text_df['section_content'] = text_df.apply(lambda x: BeautifulSoup(x.drug_text, 'html.parser').text.replace(x.section_title, '').strip().lower(),
                                           axis = 1)
text_df.head(1)
# Out:
#    product_id                                          drug_text  \
# 0        1589  <details><summary data-evt="smpcSectionOpen" i...
#
#                                   section_title  \
# 0  4.4 Special warnings and precautions for use
#
#                                      section_content
# 0  prolonged and repeated applications are inadvi...

# %%
app_data_df = pd.read_csv(data_folder+'data/drug_wp_text_matched_terms.csv')
print(app_data_df.shape)
app_data_df = app_data_df.drop_duplicates()
print(app_data_df.shape)
app_data_df.head(1)
# Out:
# (829969, 4)
# (402882, 4)
#                                               string  index        found_term  \
# 0  prolonged and repeated applications are inadvi...   55.0  hypersensitivity
#
#     meddra_id
# 0  10020751.0

# %%
building_strings = []
#ade_text_table_dict = dict(zip(text_df.product_id, text_df.section_content))
for i, row in tqdm(app_data_df.iterrows()):
  if str(row['index']) != 'nan':
    term, start_pos, ar_text = row['found_term'], int(row['index']), row['string']
    #default settings
    nwords, prop_before = 125, 0.125
    #pull the full text
    #ar_text = ade_text_table_dict[label_id]

    term_nwords = len(term)
    size_before = max(int((nwords-2*term_nwords)*prop_before), 1)
    size_after = max(int((nwords-2*term_nwords)*(1-prop_before)), 1)

    before_text = ar_text[:start_pos]
    after_text = ar_text[(start_pos+term_nwords):]

    before_parts = before_text.split()[-1*size_before:]
    after_parts = after_text.split()[:size_after]

    li = [term]
    li.extend(before_parts)
    li.append('EVENT')
    li.extend(after_parts)
    example_string = ' '.join(li)
    building_strings.append(example_string)
  else:
    building_strings.append(None)
# Out:
# 402882it [00:53, 7471.02it/s]

# %%
app_data_df['section_content'] = app_data_df['string']
app_data_df['string'] = building_strings
exact_terms_df = text_df.merge(app_data_df, on = 'section_content', how = 'left')
exact_terms_df = exact_terms_df.drop(columns = ['drug_text', 'section_content', 'section_title'])
exact_terms_df.head()
# Out:
#    product_id                                             string  index  \
# 0        1589  hypersensitivity prolonged and repeated applic...   55.0
# 1        4223  fever or have worsened after 3 days, or if sym...  155.0
# 2        4223  fructose intolerance are taken a day. patients...  369.0
# 3        4223  headache after 3 days, or if symptoms are acco...  164.0
# 4        4223  fructose effect if several are taken a day. pa...  369.0
#
#              found_term   meddra_id
# 0      hypersensitivity  10020751.0
# 1                 fever  10037660.0
# 2  fructose intolerance  10072104.0
# 3              headache  10019211.0
# 4              fructose  10063255.0

# %%
exact_terms_df.to_csv(data_folder+'data/serious/sentences-rx_method14_nwords125_clinical_bert_application_set_AR_v0120.csv', index=False)

# %% [markdown]
# ---
# ### format dataframe for onsides model

# %%
#required columns : section, drug, label_id, set_id, spl_version, pt_meddra_id, pt_meddra_term
exact_terms_df = pd.read_csv(data_folder+'data/serious/sentences-rx_method14_nwords125_clinical_bert_application_set_AR_v0120.csv')
exact_terms_df['section'] = 'AR'
exact_terms_df['set_id'] = exact_terms_df['product_id']
exact_terms_df['location'] = exact_terms_df['index']
exact_terms_df = exact_terms_df.rename(columns = {'product_id':'label_id', 'onsides_string':'string'}).drop(columns = ['index'])
print(exact_terms_df.shape)
drug_df = pd.read_csv(data_folder+'data/final_UK/drug_data.csv').rename(columns={'ingredient_name':'drug'})
drug_df['label_id'] = drug_df['product_id'].apply(lambda x: int(x.split('/')[-2]))
drug_df = drug_df[['label_id', 'drug']].drop_duplicates().groupby('label_id')['drug'].apply(set).reset_index()
drug_df['drug'] = drug_df['drug'].apply(lambda x: str(x)[1:-1].replace("'",''))
exact_terms_df = exact_terms_df.merge(drug_df[['label_id', 'drug']].drop_duplicates(), on = 'label_id', how = 'left')
print(exact_terms_df.shape)
folder = '/content/drive/MyDrive/pop_pharmacogenomics/fda/onsides-2.0.0/data/'
llt_pt = pd.read_csv(folder+'meddra_llt_pt_map.txt', delimiter = '|')
llt_pt_id_dict = dict(zip(llt_pt.llt_concept_code, llt_pt.pt_concept_code))
llt_pt_term_dict = dict(zip(llt_pt.llt_concept_code, llt_pt.pt_concept_name))
exact_terms_df['pt_meddra_id'] = exact_terms_df.meddra_id.apply(lambda x: llt_pt_id_dict[x] if x in llt_pt_id_dict.keys() else None)
exact_terms_df['pt_meddra_term'] =  exact_terms_df.meddra_id.apply(lambda x: llt_pt_term_dict[x] if x in llt_pt_term_dict.keys() else None)
print(exact_terms_df.shape)
exact_terms_df.to_csv(data_folder+'data/serious/sentences-rx_method14_nwords125_clinical_bert_application_set_AR_v0120.csv', index=False)
exact_terms_df.head(1)
# Out:
# (515103, 7)
# (515103, 8)
# (515103, 10)
#    label_id                                             string  \
# 0      1589  hypersensitivity prolonged and repeated applic...
#
#          found_term   meddra_id section  set_id  location  \
# 0  hypersensitivity  10020751.0      AR    1589      55.0
#
#                                                drug  pt_meddra_id  \
# 0  allantoin, 2,4-dichlorobenzyl alcohol, cetrimide    10020751.0
#
#      pt_meddra_term
# 0  Hypersensitivity

# %%
exact_terms_df = pd.read_csv(data_folder+'data/serious/sentences-rx_method14_nwords125_clinical_bert_application_set_AR_v0120.csv')
print(exact_terms_df.shape)
exact_terms_df = exact_terms_df[exact_terms_df.string.notna()]
exact_terms_df['spl_version'] = None
print(exact_terms_df.shape)
exact_terms_df.to_csv(data_folder+'data/serious/sentences-rx_method14_nwords125_clinical_bert_application_set_AR_v0120.csv', index=False)
# Out:
# (515103, 10)
# (515026, 11)

# %% [markdown]
# ### run onsides model

# %%
#prep onsides materials
folder = '/content/drive/MyDrive/pop_pharmacogenomics/onsides_intl/onsides'
ar_model = folder + '/bestepoch-bydrug-PMB_14-AR-125-all_222_24_25_2.5e-05_256_32.pth'
bw_model = folder + '/bestepoch-bydrug-PMB_14-AR-125-all_222_24_25_2.5e-05_256_32.pth'
import os
os.chdir('/content/drive/MyDrive/pop_pharmacogenomics/fda/onsides-2.0.0/')
# !python3 -m pip install -r requirements.txt
# Out:
# Collecting beautifulsoup4==4.11.1 (from -r requirements.txt (line 1))
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 3.7 MB/s eta 0:00:00
# Collecting nltk==3.7 (from -r requirements.txt (line 2))
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 15.9 MB/s eta 0:00:00
# Collecting numpy==1.23.4 (from -r requirements.txt (line 3))
#   Downloading numpy-1.23.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 65.5 MB/s eta 0:00:00
# Collecting pandas==1.5.1 (from -r requirements.txt (line 4))
#   Downloading pandas-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 87.6 MB/s eta 0:00:00
# Collecting psutil==5.9.3 (from -r requirements.txt (line 5))
#   Downloading psutil-5.9.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.3/292.3 kB 40.1 MB/s eta 0:00:00
# Collecting pynput==1.7.6 (from -r requirements.txt (line 6))
#   Downloading pynput-1.7.6-py2.py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 15.8 MB/s eta 0:00:00
# Collecting requests==2.28.1 (from -r requirements.txt (line 7))
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 9.9 MB/s eta 0:00:00
# Collecting scikit_learn==1.1.3 (from -r requirements.txt (line 8))
#   Downloading scikit_learn-1.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 51.0 MB/s eta 0:00:00
# Collecting torch==1.13.0 (from -r requirements.txt (line 9))
#   Downloading torch-1.13.0-cp310-cp310-manylinux1_x86_64.whl (890.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.1/890.1 MB 1.8 MB/s eta 0:00:00
# Collecting transformers==4.24.0 (from -r requirements.txt (line 10))
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 114.7 MB/s eta 0:00:00
# Collecting tqdm==4.64.1 (from -r requirements.txt (line 11))
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4==4.11.1->-r requirements.txt (line 1)) (2.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk==3.7->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk==3.7->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk==3.7->-r requirements.txt (line 2)) (2023.6.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.5.1->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.5.1->-r requirements.txt (line 4)) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pynput==1.7.6->-r requirements.txt (line 6)) (1.16.0)
# Collecting evdev>=1.3 (from pynput==1.7.6->-r requirements.txt (line 6))
#   Downloading evdev-1.6.1.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-xlib>=0.17 (from pynput==1.7.6->-r requirements.txt (line 6))
#   Downloading python_xlib-0.33-py2.py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.2/182.2 kB 27.2 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2 (from requests==2.28.1->-r requirements.txt (line 7))
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.28.1->-r requirements.txt (line 7)) (3.6)
# Collecting urllib3<1.27,>=1.21.1 (from requests==2.28.1->-r requirements.txt (line 7))
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 22.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.28.1->-r requirements.txt (line 7)) (2023.11.17)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit_learn==1.1.3->-r requirements.txt (line 8)) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn==1.1.3->-r requirements.txt (line 8)) (3.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.0->-r requirements.txt (line 9)) (4.5.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==1.13.0->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 71.0 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==1.13.0->-r requirements.txt (line 9))
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==1.13.0->-r requirements.txt (line 9))
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==1.13.0->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 58.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 10)) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 10)) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 10)) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->-r requirements.txt (line 10)) (6.0.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.24.0->-r requirements.txt (line 10))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 105.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->-r requirements.txt (line 9)) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->-r requirements.txt (line 9)) (0.42.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.24.0->-r requirements.txt (line 10)) (2023.6.0)
# Building wheels for collected packages: evdev
#   Building wheel for evdev (setup.py) ... done
#   Created wheel for evdev: filename=evdev-1.6.1-cp310-cp310-linux_x86_64.whl size=83723 sha256=6318c7a7eb4f42bc30a81353c289d19ba1ed91cd2dc06f7525cc5603ef43df6b
#   Stored in directory: /root/.cache/pip/wheels/bb/6e/51/0c0f5677bd58c532c42e13e7d93803fbf8d5d3bf5bfc5b0220
# Successfully built evdev
# Installing collected packages: tokenizers, evdev, urllib3, tqdm, python-xlib, psutil, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, numpy, charset-normalizer, beautifulsoup4, requests, pynput, pandas, nvidia-cudnn-cu11, nltk, torch, scikit_learn, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.1
#     Uninstalling tokenizers-0.15.1:
#       Successfully uninstalled tokenizers-0.15.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu121
#     Uninstalling torch-2.1.0+cu121:
#       Successfully uninstalled torch-2.1.0+cu121
#   Attempting uninstall: scikit_learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# bigframes 0.19.2 requires scikit-learn>=1.2.2, but you have scikit-learn 1.1.3 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 1.5.1 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.28.1 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 1.23.4 which is incompatible.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 1.13.0 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 1.13.0 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 1.13.0 which is incompatible.
# torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 1.13.0 which is incompatible.
# yfinance 0.2.36 requires requests>=2.31, but you have requests 2.28.1 which is incompatible.
# Successfully installed beautifulsoup4-4.11.1 charset-normalizer-2.1.1 evdev-1.6.1 nltk-3.7 numpy-1.23.4 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 pandas-1.5.1 psutil-5.9.3 pynput-1.7.6 python-xlib-0.33 requests-2.28.1 scikit_learn-1.1.3 tokenizers-0.13.3 torch-1.13.0 tqdm-4.64.1 transformers-4.24.0 urllib3-1.26.18

# %%
#use onsides model
f = data_folder+'data/serious/sentences-rx_method14_nwords125_clinical_bert_application_set_AR_v0120.csv'
# !python3 src/predict.py --model $ar_model --examples $f
# Out:
# 2024-01-28 14:36:19.788859: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-28 14:36:19.788905: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-28 14:36:19.790214: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-28 14:36:19.797303: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-28 14:36:20.860652: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading model from bestepoch-bydrug-PMB_14-AR-125-all_222_24_25_2.5e-05_256_32.pth
# Model
# -------------------
#  prefix: bestepoch-bydrug-PMB
#  network: PMB
#  refset: 14
#  refsource: all
#  refsection: AR
#  refnwords: 125
#  np_random_seed: 222
#  split_method: 24
#  EPOCHS: 25
#  LR: 2.5e-05
#  max_length: 256
#  batch_size: 32
#
# Examples
# -------------------
#  prefix: sentences-rx
#  refset: 14
#  is_split: False
#  split_no:
#  results path: /content/drive/MyDrive/pop_pharmacogenomics/onsides_intl/uk_drug_label/data/serious/bestepoch-bydrug-PMB-sentences-rx_ref14-AR-125-all_222_24_25_2.5e-05_256_32.csv.gz
#
# Setting prediction batch_size to 2X the training batch_size: 64
# Loading tokenizer from microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext...
# tokenizer_config.json: 100% 28.0/28.0 [00:00<00:00, 148kB/s]
# config.json: 100% 385/385 [00:00<00:00, 2.14MB/s]
# vocab.txt: 100% 226k/226k [00:00<00:00, 464kB/s]
# pytorch_model.bin: 100% 440M/440M [00:01<00:00, 273MB/s]
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Evaluating example data...
# 100% 8048/8048 [2:02:57<00:00,  1.09it/s]

# %%
#build tables
r = data_folder+'data/serious/bestepoch-bydrug-PMB-sentences-rx_ref14-AR-125-all_222_24_25_2.5e-05_256_32.csv.gz'
# !python3 src/create_onsides_datafiles.py --release v2.0.0-AR --results $r --examples $f
# Out:
#  prefix: bestepoch-bydrug-PMB-sentences-rx
#  refset: ref14-AR-125-all
#  np_random_seed: 222
#  split_method: 24
#  EPOCHS: 25
#  LR: 2.5e-05
#  threshold: 0.4633
#  max_length: 2.5e-05
#  batch-size: 32.csv
#  compiled file: /content/drive/MyDrive/pop_pharmacogenomics/onsides_intl/uk_drug_label/data/serious/compiled/v2.0.0/AR.csv.gz
# Loading results file...
#  res.shape: (515026, 2)
# Loding examples file...
#  ex.shape: (515026, 11)
# Concatenating results file to examples file...
# Grouping predictions by drug label and adverse event term, and taking the mean prediction score...
# /content/drive/MyDrive/pop_pharmacogenomics/fda/onsides-2.0.0/src/create_onsides_datafiles.py:97: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped = df.groupby(by=['section', 'drug', 'label_id', 'set_id', 'spl_version', 'pt_meddra_id', 'pt_meddra_term']).mean().reset_index()
# Applying the pre-determined threshold to the prediction values to get predictions...
# Predictions data frame created...
#  predictions.shape: (0, 10)
# Saving to gzipped file: /content/drive/MyDrive/pop_pharmacogenomics/onsides_intl/uk_drug_label/data/serious/compiled/v2.0.0/AR.csv.gz...

# %%
res = data_folder+'data/bestepoch-bydrug-PMB-sentences-rx_ref14-AR-125-all_222_24_25_2.5e-05_256_32.csv.gz'
ex = data_folder+'data/sentences-rx_method14_nwords125_clinical_bert_application_set_AR_v0924.csv'
#threshold = 0.463
res = pd.read_csv(res, header=None, names=['Pred0', 'Pred1'])
ex = pd.read_csv(ex)
df = pd.concat([ex, res], axis=1)
print(df.shape[0])
df = df[df.Pred0 > threshold]
print(df.shape[0])
df.head()
# Out:
# 854253
# 625380
#    label_id                 found_term  meddra_id  location  \
# 0      1589           hypersensitivity   10020751         0
# 1      1589  hypersensitivity reaction   10020751         0
# 2      1589                      hyper   10037211         0
# 3      4223                 angioedema   10002424       729
# 4      4223                      edema   10030095       734
#
#                                               string section  set_id  drug  \
# 0  hypersensitivity EVENT ypersensitivity reactio...      AR    1589   NaN
# 1  hypersensitivity reaction EVENT persensitivity...      AR    1589   NaN
# 2  hyper EVENT ypersensitivity reactions may occa...      AR    1589   NaN
# 3  angioedema presented in order of decreasing se...      AR    4223   NaN
# 4  edema in order of decreasing seriousness.a2,4-...      AR    4223   NaN
#
#    spl_version  pt_meddra_id             pt_meddra_term     Pred0  Pred1
# 0          NaN    10020751.0           Hypersensitivity  1.179923    0.0
# 1          NaN    10020751.0           Hypersensitivity  1.194894    0.0
# 2          NaN    10037211.0  Psychomotor hyperactivity  1.665707    0.0
# 3          NaN    10002424.0                 Angioedema  1.494658    0.0
# 4          NaN    10030095.0                     Oedema  2.323206    0.0

# %%
df.to_csv(data_folder+'data/ade_text_table_onsides_pred_v0924.csv', index=False)
