# %%
import os
import sys
import csv
import tqdm
import pandas as pd
from itertools import permutations
import string

# from fuzzyset import FuzzySet
from cfuzzyset import cFuzzySet as FuzzySet

from sklearn.metrics import roc_auc_score, average_precision_score, precision_recall_curve

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# this is the deep cadrme output for 199 drugs (199 instead of 200 because we're missing 1 boundary file oops)
# I dropped this file into the dropbox
Deepcadrme_guess_terms = pd.read_csv("../data/deepcadrme_guess_terms.csv")

# turn all terms to lowercase
Deepcadrme_guess_terms['term'] = Deepcadrme_guess_terms['term'].str.lower()

# %%
pd.options.display.max_rows = 4000
Deepcadrme_guess_terms.head(500)
# Out:
#              file                                               term  \
# 0     ACTEMRA.xml                 upper respiratory tract infections
# 1     ACTEMRA.xml                                    nasopharyngitis
# 2     ACTEMRA.xml                                           headache
# 3     ACTEMRA.xml                                       hypertension
# 4     ACTEMRA.xml                                      increased alt
# 5     ACTEMRA.xml                           injection site reactions
# 6     ACTEMRA.xml                                         infections
# 7     ACTEMRA.xml                 upper respiratory tract infections
# 8     ACTEMRA.xml                                    nasopharyngitis
# 9     ACTEMRA.xml                                           headache
# 10    ACTEMRA.xml                                       hypertension
# 11    ACTEMRA.xml                                      increased alt
# 12    ACTEMRA.xml              increased hepatic transaminase values
# 13    ACTEMRA.xml                                         infections
# 14    ACTEMRA.xml                                         infections
# 15    ACTEMRA.xml                                         infections
# 16    ACTEMRA.xml                                         infections
# 17    ACTEMRA.xml                 upper respiratory tract infections
# 18    ACTEMRA.xml                                    nasopharyngitis
# 19    ACTEMRA.xml                                         infections
# 20    ACTEMRA.xml                                         infections
# 21    ACTEMRA.xml                                         infections
# 22    ACTEMRA.xml                                         infections
# 23    ACTEMRA.xml                                         infections
# 24    ACTEMRA.xml                                          pneumonia
# 25    ACTEMRA.xml                            urinary tract infection
# 26    ACTEMRA.xml                                         cellulitis
# 27    ACTEMRA.xml                                      herpes zoster
# 28    ACTEMRA.xml                                    gastroenteritis
# 29    ACTEMRA.xml                                     diverticulitis
# 30    ACTEMRA.xml                                             sepsis
# 31    ACTEMRA.xml                                bacterial arthritis
# 32    ACTEMRA.xml                           opportunistic infections
# 33    ACTEMRA.xml                       gastrointestinal perforation
# 34    ACTEMRA.xml                       gastrointestinal perforation
# 35    ACTEMRA.xml                       gastrointestinal perforation
# 36    ACTEMRA.xml                                     diverticulitis
# 37    ACTEMRA.xml                   generalized purulent peritonitis
# 38    ACTEMRA.xml                               lower gi perforation
# 39    ACTEMRA.xml                                            fistula
# 40    ACTEMRA.xml                                            abscess
# 41    ACTEMRA.xml                      gastrointestinal perforations
# 42    ACTEMRA.xml                                    gi perforations
# 43    ACTEMRA.xml                                     adverse events
# 44    ACTEMRA.xml                                       hypertension
# 45    ACTEMRA.xml                                           headache
# 46    ACTEMRA.xml                                     skin reactions
# 47    ACTEMRA.xml                                               rash
# 48    ACTEMRA.xml                                           pruritus
# 49    ACTEMRA.xml                                          urticaria
# 50    ACTEMRA.xml                         hypersensitivity reactions
# 51    ACTEMRA.xml                                        anaphylaxis
# 52    ACTEMRA.xml                     decreases in neutrophil counts
# 53    ACTEMRA.xml                                 anc below 1000 per
# 54    ACTEMRA.xml                     decreases in neutrophil counts
# 55    ACTEMRA.xml                           decreases in neutrophils
# 56    ACTEMRA.xml                                         infections
# 57    ACTEMRA.xml                     decreases in neutrophil counts
# 58    ACTEMRA.xml                       decreases in platelet counts
# 59    ACTEMRA.xml                                           bleeding
# 60    ACTEMRA.xml                       decreases in platelet counts
# 61    ACTEMRA.xml                         liver enzyme abnormalities
# 62    ACTEMRA.xml                                              liver
# 63    ACTEMRA.xml                                           decrease
# 64    ACTEMRA.xml                                         elevations
# 65    ACTEMRA.xml                      increases in direct bilirubin
# 66    ACTEMRA.xml                                          hepatitis
# 67    ACTEMRA.xml                              hepatic insufficiency
# 68    ACTEMRA.xml                         liver enzyme abnormalities
# 69    ACTEMRA.xml                          ast 3 uln uln 5 uln 5 uln
# 70    ACTEMRA.xml                    alt uln 3 uln uln 5 uln uln 0.7
# 71    ACTEMRA.xml                                      elevations in
# 72    ACTEMRA.xml                                      elevations in
# 73    ACTEMRA.xml                         increases in triglycerides
# 74    ACTEMRA.xml                                      ldl increased
# 75    ACTEMRA.xml                                      hdl increased
# 76    ACTEMRA.xml                            ldl hdl ratio increased
# 77    ACTEMRA.xml                                    elevated lipids
# 78    ACTEMRA.xml                     elevations in lipid parameters
# 79    ACTEMRA.xml                          hypersensitivity reaction
# 80    ACTEMRA.xml                            neutralizing antibodies
# 81    ACTEMRA.xml                                       malignancies
# 82    ACTEMRA.xml                                       malignancies
# 83    ACTEMRA.xml                                       malignancies
# 84    ACTEMRA.xml                  upper respiratory tract infection
# 85    ACTEMRA.xml                                    nasopharyngitis
# 86    ACTEMRA.xml                                           headache
# 87    ACTEMRA.xml                                       hypertension
# 88    ACTEMRA.xml                                      alt increased
# 89    ACTEMRA.xml                                          dizziness
# 90    ACTEMRA.xml                                         bronchitis
# 91    ACTEMRA.xml                                               rash
# 92    ACTEMRA.xml                                   mouth ulceration
# 93    ACTEMRA.xml                                     abdominal pain
# 94    ACTEMRA.xml                                              upper
# 95    ACTEMRA.xml                                          gastritis
# 96    ACTEMRA.xml                             transaminase increased
# 97    ACTEMRA.xml                                oral herpes simplex
# 98    ACTEMRA.xml                                         stomatitis
# 99    ACTEMRA.xml                                      gastric ulcer
# 100   ACTEMRA.xml                                   weight increased
# 101   ACTEMRA.xml                          total bilirubin increased
# 102   ACTEMRA.xml                                         leukopenia
# 103   ACTEMRA.xml                                   edema peripheral
# 104   ACTEMRA.xml                                            dyspnea
# 105   ACTEMRA.xml                                              cough
# 106   ACTEMRA.xml                                     conjunctivitis
# 107   ACTEMRA.xml                                    nephrolithiasis
# 108   ACTEMRA.xml                                     hypothyroidism
# 109   ACTEMRA.xml                           injection site reactions
# 110   ACTEMRA.xml                           injection site reactions
# 111   ACTEMRA.xml                           injection site reactions
# 112   ACTEMRA.xml                                           erythema
# 113   ACTEMRA.xml                                           pruritus
# 114   ACTEMRA.xml                                               pain
# 115   ACTEMRA.xml                                           hematoma
# 116   ACTEMRA.xml                                               anti
# 117   ACTEMRA.xml                            neutralizing antibodies
# 118   ACTEMRA.xml                            neutralizing antibodies
# 119   ACTEMRA.xml                       decrease in neutrophil count
# 120   ACTEMRA.xml                           decreases in neutrophils
# 121   ACTEMRA.xml                                         infections
# 122   ACTEMRA.xml                         decrease in platelet count
# 123   ACTEMRA.xml                                       elevation in
# 124   ACTEMRA.xml                    elevations in total cholesterol
# 125   ACTEMRA.xml                                    increase in ldl
# 126   ACTEMRA.xml                                         infections
# 127   ACTEMRA.xml                                    nasopharyngitis
# 128   ACTEMRA.xml                 upper respiratory tract infections
# 129   ACTEMRA.xml                                         infections
# 130   ACTEMRA.xml                                         infections
# 131   ACTEMRA.xml                         infusion related reactions
# 132   ACTEMRA.xml                                           headache
# 133   ACTEMRA.xml                                             nausea
# 134   ACTEMRA.xml                                        hypotension
# 135   ACTEMRA.xml                                          dizziness
# 136   ACTEMRA.xml                                        hypotension
# 137   ACTEMRA.xml                         hypersensitivity reactions
# 138   ACTEMRA.xml                          hypersensitivity reaction
# 139   ACTEMRA.xml                      decrease in neutrophil counts
# 140   ACTEMRA.xml                           decreases in neutrophils
# 141   ACTEMRA.xml                                         infections
# 142   ACTEMRA.xml                         decrease in platelet count
# 143   ACTEMRA.xml                                           bleeding
# 144   ACTEMRA.xml                                       elevation in
# 145   ACTEMRA.xml                     elevation in total cholesterol
# 146   ACTEMRA.xml                                   elevation in ldl
# 147   ACTEMRA.xml                  upper respiratory tract infection
# 148   ACTEMRA.xml                                           headache
# 149   ACTEMRA.xml                                    nasopharyngitis
# 150   ACTEMRA.xml                                           diarrhea
# 151   ACTEMRA.xml                                         infections
# 152   ACTEMRA.xml                                         infections
# 153   ACTEMRA.xml                                         infections
# 154   ACTEMRA.xml                                         infections
# 155   ACTEMRA.xml                                         infections
# 156   ACTEMRA.xml                                          pneumonia
# 157   ACTEMRA.xml                                    gastroenteritis
# 158   ACTEMRA.xml                                          varicella
# 159   ACTEMRA.xml                                       otitis media
# 160   ACTEMRA.xml                     macrophage activation syndrome
# 161   ACTEMRA.xml                                                mas
# 162   ACTEMRA.xml                                                mas
# 163   ACTEMRA.xml                                                mas
# 164   ACTEMRA.xml                                                mas
# 165   ACTEMRA.xml                                                mas
# 166   ACTEMRA.xml                                                mas
# 167   ACTEMRA.xml                                                mas
# 168   ACTEMRA.xml                                         angioedema
# 169   ACTEMRA.xml                                               rash
# 170   ACTEMRA.xml                                          urticaria
# 171   ACTEMRA.xml                                           diarrhea
# 172   ACTEMRA.xml                              epigastric discomfort
# 173   ACTEMRA.xml                                         arthralgia
# 174   ACTEMRA.xml                                           headache
# 175   ACTEMRA.xml                                          urticaria
# 176   ACTEMRA.xml                                        anaphylaxis
# 177   ACTEMRA.xml                                          urticaria
# 178   ACTEMRA.xml                                         angioedema
# 179   ACTEMRA.xml                              anaphylactic reaction
# 180   ACTEMRA.xml                     macrophage activation syndrome
# 181   ACTEMRA.xml                       decrease in neutrophil below
# 182   ACTEMRA.xml                         decreased neutrophil count
# 183   ACTEMRA.xml                            decrease in neutrophils
# 184   ACTEMRA.xml                                         infections
# 185   ACTEMRA.xml                         decrease in platelet count
# 186   ACTEMRA.xml                           decreased platelet count
# 187   ACTEMRA.xml                                           bleeding
# 188   ACTEMRA.xml                                          elevation
# 189   ACTEMRA.xml                                       elevation in
# 190   ACTEMRA.xml                     elevation in total cholesterol
# 191   ACTEMRA.xml                                   elevation in ldl
# 192   ACTEMRA.xml                     elevations in lipid parameters
# 193   ACTEMRA.xml                                              fatal
# 194   ACTEMRA.xml                                        anaphylaxis
# 195   ACTEMRA.xml                           stevens johnson syndrome
# 196   ACTEMRA.xml                                         infections
# 197   ACTEMRA.xml                         hypersensitivity reactions
# 198   ACTEMRA.xml                                        anaphylaxis
# 199   ACTEMRA.xml                                              death
# 200   ACTEMRA.xml                                              fatal
# 201   ACTEMRA.xml                                         infections
# 202   ACTEMRA.xml                                         infections
# 203   ACTEMRA.xml                                          pneumonia
# 204   ACTEMRA.xml                            urinary tract infection
# 205   ACTEMRA.xml                                         cellulitis
# 206   ACTEMRA.xml                                      herpes zoster
# 207   ACTEMRA.xml                                    gastroenteritis
# 208   ACTEMRA.xml                                     diverticulitis
# 209   ACTEMRA.xml                                             sepsis
# 210   ACTEMRA.xml                                bacterial arthritis
# 211   ACTEMRA.xml                                       tuberculosis
# 212   ACTEMRA.xml                                       cryptococcus
# 213   ACTEMRA.xml                                      aspergillosis
# 214   ACTEMRA.xml                                        candidiasis
# 215   ACTEMRA.xml                                     pneumocystosis
# 216   ACTEMRA.xml                                         infections
# 217   ACTEMRA.xml                                     histoplasmosis
# 218   ACTEMRA.xml                                 coccidioidomycosis
# 219   ACTEMRA.xml                                        listeriosis
# 220   ACTEMRA.xml                                 viral reactivation
# 221   ACTEMRA.xml                         herpes zoster exacerbation
# 222   ACTEMRA.xml                           hepatitis b reactivation
# 223   ACTEMRA.xml                       gastrointestinal perforation
# 224   ACTEMRA.xml                                     diverticulitis
# 225   ACTEMRA.xml                                        neutropenia
# 226   ACTEMRA.xml                                         infections
# 227   ACTEMRA.xml                                        neutropenia
# 228   ACTEMRA.xml                       reduction in platelet counts
# 229   ACTEMRA.xml                                       reduction in
# 230   ACTEMRA.xml                                           bleeding
# 231   ACTEMRA.xml                            transaminase elevations
# 232   ACTEMRA.xml                                     hepatic injury
# 233   ACTEMRA.xml                        elevations in transaminases
# 234   ACTEMRA.xml                                   elevation in ast
# 235   ACTEMRA.xml                                   elevation in alt
# 236   ACTEMRA.xml                                          increases
# 237   ACTEMRA.xml                             liver enzyme elevation
# 238   ACTEMRA.xml                                     low neutrophil
# 239   ACTEMRA.xml                                                low
# 240   ACTEMRA.xml                                   lipid elevations
# 241   ACTEMRA.xml                                       malignancies
# 242   ACTEMRA.xml                                       malignancies
# 243   ACTEMRA.xml                                       malignancies
# 244   ACTEMRA.xml                         hypersensitivity reactions
# 245   ACTEMRA.xml                                        anaphylaxis
# 246   ACTEMRA.xml                                anaphylactic events
# 247   ACTEMRA.xml                                              fatal
# 248   ACTEMRA.xml                                        anaphylaxis
# 249   ACTEMRA.xml                         hypersensitivity reactions
# 250   ACTEMRA.xml                         hypersensitivity reactions
# 251   ACTEMRA.xml                         hypersensitivity reactions
# 252   ACTEMRA.xml                               generalized erythema
# 253   ACTEMRA.xml                                               rash
# 254   ACTEMRA.xml                                           uticaria
# 255   ACTEMRA.xml                         hypersensitivity reactions
# 256   ACTEMRA.xml                                        anaphylaxis
# 257   ACTEMRA.xml                                              death
# 258   ACTEMRA.xml                                   hypersensitivity
# 259   ACTEMRA.xml                                 anaphylaxis events
# 260   ACTEMRA.xml                                   hypersensitivity
# 261   ACTEMRA.xml                                      demyelinating
# 262   ACTEMRA.xml                                 multiple sclerosis
# 263   ACTEMRA.xml  chronic inflammatory demyelinating polyneuropathy
# 264   ACTEMRA.xml                                         infections
# 265   ACTEMRA.xml                                         infections
# 266   ACTEMRA.xml                                         infections
# 267   ACTEMRA.xml                                              death
# 268   ACTEMRA.xml                                         infections
# 269   ACTEMRA.xml                                active tuberculosis
# 270   ACTEMRA.xml                         invasive fungal infections
# 271   ACTEMRA.xml                                        candidiasis
# 272   ACTEMRA.xml                                      aspergillosis
# 273   ACTEMRA.xml                                       pneumocystis
# 274   ACTEMRA.xml                         invasive fungal infections
# 275   ACTEMRA.xml          infections due to opportunistic pathogens
# 276   ACTEMRA.xml                                         infections
# 277   ACTEMRA.xml                                         infections
# 278   ACTEMRA.xml                                              death
# 279   ACTEMRA.xml                                       tuberculosis
# 280   ACTEMRA.xml                                                 tb
# 281   ACTEMRA.xml        adverse events associated with the infusion
# 282   ACTEMRA.xml  decreases in neutrophil counts below 1000 per ...
# 283   ACTEMRA.xml                                          anc below
# 284   ACTEMRA.xml  decreases in platelet counts below 100,000 per...
# 285   ACTEMRA.xml        ast u l ) uln to 3 uln 3 uln to 5 uln 5 uln
# 286   ACTEMRA.xml        alt u l ) uln to 3 uln 3 uln to 5 uln 5 uln
# 287   ACTEMRA.xml               positive anti tocilizumab antibodies
# 288   ACTEMRA.xml                                       neutralizing
# 289   ACTEMRA.xml                               abdominal pain upper
# 290   ACTEMRA.xml                                   anti tocilizumab
# 291   ACTEMRA.xml                        anti tocilizumab antibodies
# 292   ACTEMRA.xml        decrease in neutrophil count below 1 10 9 l
# 293   ACTEMRA.xml                                 elevation in 3 uln
# 294   ACTEMRA.xml               positive anti tocilizumab antibodies
# 295   ACTEMRA.xml                decrease in neutrophil counts below
# 296   ACTEMRA.xml            decrease in neutrophil below 1 10 9 per
# 297   ACTEMRA.xml                                       elevation in
# 298   ACTEMRA.xml                                   gastrointestinal
# 299   ACTEMRA.xml                                     gi perforation
# 300   ACTEMRA.xml                               infections pathogens
# 301   ACTEMRA.xml                             reduction in platelets
# 302   ACTEMRA.xml                                       increases in
# 303   ACTEMRA.xml                               low neutrophil count
# 304   ACTEMRA.xml                                 low platelet count
# 305   ACTEMRA.xml                        active tuberculosis disease
# 306   ACTEMRA.xml                                           invasive
# 307   ACTEMRA.xml                                         infections
# 308   ACTEMRA.xml                              infections infections
# 309   ACTEMRA.xml                            anc below 1000 per mm 3
# 310   ACTEMRA.xml       decreases in neutrophils below 1000 per mm 3
# 311   ACTEMRA.xml                             liver enzyme elevation
# 312   ACTEMRA.xml                                ast uln 3 uln 5 uln
# 313   ACTEMRA.xml                      alt u uln 3 uln uln 5 uln uln
# 314   ACTEMRA.xml                                     injection site
# 315   ACTEMRA.xml                        anti tocilizumab antibodies
# 316   ACTEMRA.xml                                      elevation uln
# 317   ACTEMRA.xml                       gastrointestinal perforation
# 318   ACTEMRA.xml                           opportunistic infections
# 319   ACTEMRA.xml                                         elevations
# 320   ACTEMRA.xml                         hypersensitivity reactions
# 321   ACTEMRA.xml                            demyelinating disorders
# 322  ADCETRIS.xml                              peripheral neuropathy
# 323  ADCETRIS.xml                                        anaphylaxis
# 324  ADCETRIS.xml                                 infusion reactions
# 325  ADCETRIS.xml                             hematologic toxicities
# 326  ADCETRIS.xml                                         infections
# 327  ADCETRIS.xml                           opportunistic infections
# 328  ADCETRIS.xml                               tumor lysis syndrome
# 329  ADCETRIS.xml                                 increased toxicity
# 330  ADCETRIS.xml                                 increased toxicity
# 331  ADCETRIS.xml                                     hepatotoxicity
# 332  ADCETRIS.xml         progressive multifocal leukoencephalopathy
# 333  ADCETRIS.xml                                 pulmonary toxicity
# 334  ADCETRIS.xml                             dermatologic reactions
# 335  ADCETRIS.xml                                        neutropenia
# 336  ADCETRIS.xml                      peripheral sensory neuropathy
# 337  ADCETRIS.xml                                            fatigue
# 338  ADCETRIS.xml                                             nausea
# 339  ADCETRIS.xml                                             anemia
# 340  ADCETRIS.xml                  upper respiratory tract infection
# 341  ADCETRIS.xml                                           diarrhea
# 342  ADCETRIS.xml                                            pyrexia
# 343  ADCETRIS.xml                                               rash
# 344  ADCETRIS.xml                                   thrombocytopenia
# 345  ADCETRIS.xml                                              cough
# 346  ADCETRIS.xml                                           vomiting
# 347  ADCETRIS.xml                                        neutropenia
# 348  ADCETRIS.xml                      peripheral sensory neuropathy
# 349  ADCETRIS.xml                                   thrombocytopenia
# 350  ADCETRIS.xml                                             anemia
# 351  ADCETRIS.xml                  upper respiratory tract infection
# 352  ADCETRIS.xml                                            fatigue
# 353  ADCETRIS.xml                        peripheral motor neuropathy
# 354  ADCETRIS.xml                                             nausea
# 355  ADCETRIS.xml                                              cough
# 356  ADCETRIS.xml                                           diarrhea
# 357  ADCETRIS.xml                                        neutropenia
# 358  ADCETRIS.xml                      peripheral sensory neuropathy
# 359  ADCETRIS.xml                                            fatigue
# 360  ADCETRIS.xml                                             nausea
# 361  ADCETRIS.xml                                             anemia
# 362  ADCETRIS.xml                  upper respiratory tract infection
# 363  ADCETRIS.xml                                           diarrhea
# 364  ADCETRIS.xml                                            pyrexia
# 365  ADCETRIS.xml                                               rash
# 366  ADCETRIS.xml                                   thrombocytopenia
# 367  ADCETRIS.xml                                              cough
# 368  ADCETRIS.xml                                           vomiting
# 369  ADCETRIS.xml                                        neutropenia
# 370  ADCETRIS.xml                      peripheral sensory neuropathy
# 371  ADCETRIS.xml                                   thrombocytopenia
# 372  ADCETRIS.xml                                             anemia
# 373  ADCETRIS.xml                  upper respiratory tract infection
# 374  ADCETRIS.xml                                            fatigue
# 375  ADCETRIS.xml                        peripheral motor neuropathy
# 376  ADCETRIS.xml                                             nausea
# 377  ADCETRIS.xml                                              cough
# 378  ADCETRIS.xml                                           diarrhea
# 379  ADCETRIS.xml                                        neutropenia
# 380  ADCETRIS.xml                      peripheral sensory neuropathy
# 381  ADCETRIS.xml                                            fatigue
# 382  ADCETRIS.xml                  upper respiratory tract infection
# 383  ADCETRIS.xml                                             nausea
# 384  ADCETRIS.xml                                           diarrhea
# 385  ADCETRIS.xml                                             anemia
# 386  ADCETRIS.xml                                            pyrexia
# 387  ADCETRIS.xml                                   thrombocytopenia
# 388  ADCETRIS.xml                                               rash
# 389  ADCETRIS.xml                                     abdominal pain
# 390  ADCETRIS.xml                                              cough
# 391  ADCETRIS.xml                                           vomiting
# 392  ADCETRIS.xml                                        neutropenia
# 393  ADCETRIS.xml                                             anemia
# 394  ADCETRIS.xml                      peripheral sensory neuropathy
# 395  ADCETRIS.xml                                            fatigue
# 396  ADCETRIS.xml                                             nausea
# 397  ADCETRIS.xml                                            pyrexia
# 398  ADCETRIS.xml                                               rash
# 399  ADCETRIS.xml                                           diarrhea
# 400  ADCETRIS.xml                                               pain
# 401  ADCETRIS.xml                                        neutropenia
# 402  ADCETRIS.xml                                             anemia
# 403  ADCETRIS.xml                                   thrombocytopenia
# 404  ADCETRIS.xml                                    lymphadenopathy
# 405  ADCETRIS.xml                      peripheral sensory neuropathy
# 406  ADCETRIS.xml                        peripheral motor neuropathy
# 407  ADCETRIS.xml                                           headache
# 408  ADCETRIS.xml                                          dizziness
# 409  ADCETRIS.xml                                            fatigue
# 410  ADCETRIS.xml                                            pyrexia
# 411  ADCETRIS.xml                                             chills
# 412  ADCETRIS.xml                                               pain
# 413  ADCETRIS.xml                                   edema peripheral
# 414  ADCETRIS.xml                  upper respiratory tract infection
# 415  ADCETRIS.xml                                             nausea
# 416  ADCETRIS.xml                                           diarrhea
# 417  ADCETRIS.xml                                     abdominal pain
# 418  ADCETRIS.xml                                           vomiting
# 419  ADCETRIS.xml                                       constipation
# 420  ADCETRIS.xml                                               rash
# 421  ADCETRIS.xml                                           pruritus
# 422  ADCETRIS.xml                                           alopecia
# 423  ADCETRIS.xml                                       night sweats
# 424  ADCETRIS.xml                                           dry skin
# 425  ADCETRIS.xml                                              cough
# 426  ADCETRIS.xml                                            dyspnea
# 427  ADCETRIS.xml                                 oropharyngeal pain
# 428  ADCETRIS.xml                                         arthralgia
# 429  ADCETRIS.xml                                            myalgia
# 430  ADCETRIS.xml                                          back pain
# 431  ADCETRIS.xml                                  pain in extremity
# 432  ADCETRIS.xml                                      muscle spasms
# 433  ADCETRIS.xml                                           insomnia
# 434  ADCETRIS.xml                                            anxiety
# 435  ADCETRIS.xml                                 decreased appetite
# 436  ADCETRIS.xml                                   weight decreased
# 437  ADCETRIS.xml                                        neutropenia
# 438  ADCETRIS.xml                                   thrombocytopenia
# 439  ADCETRIS.xml                                             anemia
# 440  ADCETRIS.xml                      peripheral sensory neuropathy
# 441  ADCETRIS.xml                        peripheral motor neuropathy
# 442  ADCETRIS.xml                                           headache
# 443  ADCETRIS.xml                  upper respiratory tract infection
# 444  ADCETRIS.xml                                            fatigue
# 445  ADCETRIS.xml                                            pyrexia
# 446  ADCETRIS.xml                                             chills
# 447  ADCETRIS.xml                                             nausea
# 448  ADCETRIS.xml                                           diarrhea
# 449  ADCETRIS.xml                                           vomiting
# 450  ADCETRIS.xml                                     abdominal pain
# 451  ADCETRIS.xml                                       constipation
# 452  ADCETRIS.xml                                              cough
# 453  ADCETRIS.xml                                            dyspnea
# 454  ADCETRIS.xml                                   weight decreased
# 455  ADCETRIS.xml                                         arthralgia
# 456  ADCETRIS.xml                                      muscle spasms
# 457  ADCETRIS.xml                                            myalgia
# 458  ADCETRIS.xml                                           pruritus
# 459  ADCETRIS.xml                                 decreased appetite
# 460  ADCETRIS.xml                                         neuropathy
# 461  ADCETRIS.xml                                         neuropathy
# 462  ADCETRIS.xml                                residual neuropathy
# 463  ADCETRIS.xml                                         neuropathy
# 464  ADCETRIS.xml                                         neuropathy
# 465  ADCETRIS.xml                                residual neuropathy
# 466  ADCETRIS.xml                                        anaphylaxis
# 467  ADCETRIS.xml                         infusion related reactions
# 468  ADCETRIS.xml                         infusion related reactions
# 469  ADCETRIS.xml                                           infusion
# 470  ADCETRIS.xml                                             chills
# 471  ADCETRIS.xml                                             nausea
# 472  ADCETRIS.xml                                            dyspnea
# 473  ADCETRIS.xml                                           pruritus
# 474  ADCETRIS.xml                                            pyrexia
# 475  ADCETRIS.xml                                              cough
# 476  ADCETRIS.xml                         infusion related reactions
# 477  ADCETRIS.xml                         infusion related reactions
# 478  ADCETRIS.xml                         infusion related reactions
# 479  ADCETRIS.xml                         infusion related reactions
# 480  ADCETRIS.xml                                             nausea
# 481  ADCETRIS.xml                                             chills
# 482  ADCETRIS.xml                                            dyspnea
# 483  ADCETRIS.xml                                           headache
# 484  ADCETRIS.xml                                           pruritus
# 485  ADCETRIS.xml                                               rash
# 486  ADCETRIS.xml                                          back pain
# 487  ADCETRIS.xml                                           vomiting
# 488  ADCETRIS.xml                  non infectious pulmonary toxicity
# 489  ADCETRIS.xml                                              cough
# 490  ADCETRIS.xml                                            dyspnea
# 491  ADCETRIS.xml                             interstitial the chest
# 492  ADCETRIS.xml                                 pulmonary toxicity
# 493  ADCETRIS.xml                                 pulmonary toxicity
# 494  ADCETRIS.xml                        peripheral motor neuropathy
# 495  ADCETRIS.xml                                     abdominal pain
# 496  ADCETRIS.xml                                 pulmonary embolism
# 497  ADCETRIS.xml                                        pneumonitis
# 498  ADCETRIS.xml                                       pneumothorax
# 499  ADCETRIS.xml                                     pyelonephritis
#
#                                      start            len
# 0                                      410             34
# 1                                      446             15
# 2                                      463              8
# 3                                      473             12
# 449                                  14114              8
# 450                                  14231             14
# 451                                  14348             12
# 452                                  14587              5
# 453                                  14704              7
# 454                                  14938             16
# 455                                  15177             10
# 456                                  15294             13
# 457                                  15411              7
# 458                                  15645              8
# 459                                  15879             18
# 460                                  16135             10
# 461                                  16281             10
# 462                                  16301             19
# 463                                  16438             10
# 464                                  16819             10
# 465                                  16871             19
# 466                                  17019             11
# 467                                  17100             26
# 468                                  17178             26
# 469                                  17319              8
# 470                                  17351              6
# 471                                  17364              6
# 472                                  17377              7
# 473                                  17391              8
# 474                                  17406              7
# 475                                  17424              5
# 476                                  17452             26
# 477                                  17673             26
# 478                                  17712             26
# 479                                  17811             26
# 480                                  17843              6
# 481                                  17856              6
# 482                                  17869              7
# 483                                  17883              8
# 484                                  17898              8
# 485                                  17913              4
# 486                                  17924              9
# 487                                  17944              8
# 488                                  18114             33
# 489                                  18287              5
# 490                                  18297              7
# 491                          1,830,618,417           12,9
# 492                                  18602             18
# 493                                  18689             18
# 494                                  19137             27
# 495                                  19171             14
# 496                                  19192             18
# 497                                  19217             11
# 498                                  19235             12
# 499                                  19254             14

# %%
# Load all the strings from meddra 23.1 and map them to the preferred term id
fh = open('../data/meddra_pt_llt_map_omop_v23.1.csv')
reader = csv.reader(fh)
header = next(reader)

meddra_strings = dict()
meddra_ids = dict()
meddra_sorted_fuzzyset = FuzzySet()

for pt_concept_id, pt_concept_name, pt_meddra_id, llt_concept_id, llt_concept_name, llt_meddra_id in reader:
        
    # PT
    sorted_pt_concept_name = ' '.join(sorted(pt_concept_name.lower().split()))
    meddra_sorted_fuzzyset.add(sorted_pt_concept_name)
    meddra_strings[sorted_pt_concept_name] = pt_meddra_id
    meddra_ids[pt_meddra_id] = sorted_pt_concept_name
    
    # LLT
    sorted_llt_concept_name = ' '.join(sorted(llt_concept_name.lower().split()))
    meddra_sorted_fuzzyset.add(sorted_llt_concept_name)
    meddra_strings[sorted_llt_concept_name] = pt_meddra_id
    meddra_ids[pt_meddra_id] = sorted_pt_concept_name

fh.close()

len(meddra_strings)
# Out:
# 59760

# %%
# Idenify exact matches 
Deepcadrme_guess_terms["match_method"] = "exact" 

# just match stuff in the dictionary
Deepcadrme_guess_terms['proposed_meddra_term'] = Deepcadrme_guess_terms['term'].map(meddra_strings)

for row in range(len(Deepcadrme_guess_terms)):
    term = Deepcadrme_guess_terms.term[row]
    if term in meddra_strings:
        # exact match found
        continue
    if pd.isna(term):
        # nan
        continue
    if term == '.': # i don't know why, some terms are just periods--maybe we need preprocessing before
        # nan
        continue
    Deepcadrme_guess_terms.loc[row, 'match_method'] = "fuzzy"

# %%
# these are the terms to match
Deepcadrme_guess_terms.term[Deepcadrme_guess_terms["match_method"] == "fuzzy"]

# these are the total number of terms
Deepcadrme_guess_terms.term

len(Deepcadrme_guess_terms.term[Deepcadrme_guess_terms["match_method"] == "fuzzy"]), len(Deepcadrme_guess_terms.term)
# Out:
# (12830, 27131)

# %%
exact_matches = len(Deepcadrme_guess_terms.term)-len(Deepcadrme_guess_terms.term[Deepcadrme_guess_terms["match_method"] == "fuzzy"])
exact_matches
# Out:
# 14301

# %%
## a note here is that there are a few that are nans and punucation marks 
# that I took out, which is why 12830 + 14301 =/= 27131 exactly
# might need to do some preprocessing the next time we do this to prevent

# %% [markdown]
# ## FuzzySet

# %%
match_scores = list()
match_labels = list()

# we iterate over the rows again
for row in tqdm.tqdm(range(len(Deepcadrme_guess_terms))):
    
    if Deepcadrme_guess_terms.match_method[row] == "exact":
        continue
    
    a = Deepcadrme_guess_terms.term[row]
    
    sorted_a = ' '.join(sorted(a.split()))
    
    fuzzyset_match = meddra_sorted_fuzzyset.get(sorted_a)
    
    match_scores.append(fuzzyset_match[0][0])
           
    pred_meddra_pt_id = meddra_strings[sorted(fuzzyset_match)[0][1]]
        
    if fuzzyset_match[0][0] >= 0.88: 
        Deepcadrme_guess_terms.loc[row, 'proposed_meddra_term'] = pred_meddra_pt_id
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 27131/27131 [03:02<00:00, 148.54it/s]

# %%
# some post processing of the resulting df 

# get rid of anything that isn't matched since we set the threshold to 0.88
Deepcadrme_guess_terms = Deepcadrme_guess_terms.dropna() 
Deepcadrme_guess_terms.reset_index(drop=True)
# Out:
#               file                                term       start  len  \
# 0      ACTEMRA.xml  upper respiratory tract infections         410   34
# 1      ACTEMRA.xml                     nasopharyngitis         446   15
# 2      ACTEMRA.xml                            headache         463    8
# 3      ACTEMRA.xml                        hypertension         473   12
# 4      ACTEMRA.xml                       increased alt         487   13
# ...            ...                                 ...         ...  ...
# 19764  ZYKADIA.xml                         bradycardia        7104   11
# 19765  ZYKADIA.xml                        pancreatitis        8326   12
# 19766  ZYKADIA.xml                       alt increased  56,695,674  3,9
# 19767  ZYKADIA.xml                       ast increased  57,505,755  3,9
# 19768  ZYKADIA.xml                  torsade de pointes        4465   18
#
#       match_method proposed_meddra_term
# 0            fuzzy             10046306
# 1            exact             10028810
# 2            exact             10019211
# 3            exact             10020772
# 4            fuzzy             10001551
# ...            ...                  ...
# 19764        exact             10006093
# 19765        exact             10033645
# 19766        exact             10001551
# 19767        exact             10003481
# 19768        fuzzy             10044066
#
# [19769 rows x 6 columns]

# %%
# just for completeness and for sanity checks, add new column wtih string corresponding to the meddra term
# fill in the meddra term (the text of it) in the next column

# meddra_ids = {y: x for x, y in meddra_strings.items()}

Deepcadrme_guess_terms['proposed_meddra_strings'] = Deepcadrme_guess_terms['proposed_meddra_term'].map(meddra_ids)
Deepcadrme_guess_terms.tail(200)
# Out:
#               file                                   term            start  \
# 26853  ZYDELIG.xml                              pneumonia             7626
# 26855  ZYDELIG.xml                               diarrhea             8245
# 26856  ZYDELIG.xml                                 nausea             8354
# 26857  ZYDELIG.xml                         abdominal pain             8463
# 26858  ZYDELIG.xml                               vomiting             8572
# 26859  ZYDELIG.xml                                fatigue             8738
# 26860  ZYDELIG.xml                                pyrexia             8847
# 26861  ZYDELIG.xml                               asthenia             8956
# 26862  ZYDELIG.xml                       peripheral edema             9065
# 26863  ZYDELIG.xml      upper respiratory tract infection             9229
# 26947  ZYDELIG.xml                 intestinal perforation             2120
# 26953  ZYKADIA.xml              gastrointestinal toxicity              162
# 26954  ZYKADIA.xml                         hepatotoxicity              231
# 26955  ZYKADIA.xml              interstitial lung disease              289
# 26956  ZYKADIA.xml                            pneumonitis              315
# 26958  ZYKADIA.xml                          hyperglycemia              471
# 26959  ZYKADIA.xml                            bradycardia              528
# 26960  ZYKADIA.xml                           pancreatitis              616
# 26961  ZYKADIA.xml                               diarrhea              751
# 26962  ZYKADIA.xml                                 nausea              761
# 26964  ZYKADIA.xml                               vomiting              793
# 26965  ZYKADIA.xml                         abdominal pain              803
# 26966  ZYKADIA.xml                                fatigue              819
# 26967  ZYKADIA.xml                     decreased appetite              828
# 26968  ZYKADIA.xml                           constipation              852
# 26969  ZYKADIA.xml                          increased alt             2112
# 26970  ZYKADIA.xml                                 nausea             2133
# 26971  ZYKADIA.xml                          increased ast             2147
# 26972  ZYKADIA.xml                               diarrhea             2168
# 26973  ZYKADIA.xml                               vomiting             2188
# 26974  ZYKADIA.xml                             convulsion             2286
# 26975  ZYKADIA.xml                              pneumonia             2298
# 26977  ZYKADIA.xml                            pneumonitis             2313
# 26978  ZYKADIA.xml                                dyspnea             2326
# 26979  ZYKADIA.xml                            dehydration             2335
# 26980  ZYKADIA.xml                          hyperglycemia             2348
# 26981  ZYKADIA.xml                                 nausea             2367
# 26983  ZYKADIA.xml                              pneumonia             2475
# 26984  ZYKADIA.xml                    respiratory failure             2499
# 26986  ZYKADIA.xml                            pneumonitis             2524
# 26987  ZYKADIA.xml                           pneumothorax             2537
# 26988  ZYKADIA.xml                     gastric hemorrhage             2551
# 26989  ZYKADIA.xml  general physical health deterioration             2571
# 26990  ZYKADIA.xml                 pulmonary tuberculosis             2610
# 26991  ZYKADIA.xml                      cardiac tamponade             2634
# 26992  ZYKADIA.xml                                 sepsis             2657
# 26993  ZYKADIA.xml                              pneumonia             2895
# 26995  ZYKADIA.xml                            pneumonitis             2910
# 26996  ZYKADIA.xml                     decreased appetite             2927
# 26997  ZYKADIA.xml                         abdominal pain             3311
# 26998  ZYKADIA.xml                         abdominal pain             3327
# 26999  ZYKADIA.xml                   upper abdominal pain             3343
# 27000  ZYKADIA.xml                   abdominal discomfort             3365
# 27001  ZYKADIA.xml                  epigastric discomfort             3387
# 27002  ZYKADIA.xml                    esophageal disorder             3414
# 27003  ZYKADIA.xml                              dyspepsia             3435
# 27004  ZYKADIA.xml        gastroesophageal reflux disease             3446
# 27005  ZYKADIA.xml                              dysphagia             3479
# 27006  ZYKADIA.xml                                fatigue             3494
# 27007  ZYKADIA.xml                                fatigue             3503
# 27008  ZYKADIA.xml                               asthenia             3512
# 27009  ZYKADIA.xml                                   rash             3526
# 27010  ZYKADIA.xml                                   rash             3532
# 27011  ZYKADIA.xml                     maculopapular rash             3538
# 27012  ZYKADIA.xml                   acneiform dermatitis             3558
# 27013  ZYKADIA.xml                               diarrhea             3806
# 27014  ZYKADIA.xml                                 nausea             3860
# 27015  ZYKADIA.xml                               vomiting             3914
# 27016  ZYKADIA.xml                         abdominal pain             3968
# 27017  ZYKADIA.xml                           constipation             4030
# 27018  ZYKADIA.xml                    esophageal disorder             4085
# 27019  ZYKADIA.xml                                fatigue             4247
# 27020  ZYKADIA.xml                     decreased appetite             4379
# 27021  ZYKADIA.xml                                   rash             4521
# 27022  ZYKADIA.xml              interstitial lung disease             4665
# 27023  ZYKADIA.xml                            pneumonitis             4691
# 27024  ZYKADIA.xml                             neuropathy             4867
# 27025  ZYKADIA.xml                            paresthesia             4897
# 27026  ZYKADIA.xml                      muscular weakness             4910
# 27027  ZYKADIA.xml                       gait disturbance             4929
# 27028  ZYKADIA.xml                  peripheral neuropathy             4947
# 27029  ZYKADIA.xml                           hypoesthesia             4970
# 27030  ZYKADIA.xml          peripheral sensory neuropathy             4984
# 27031  ZYKADIA.xml                            dysesthesia             5015
# 27032  ZYKADIA.xml                              neuralgia             5028
# 27033  ZYKADIA.xml            peripheral motor neuropathy             5039
# 27034  ZYKADIA.xml                              hypotonia             5068
# 27035  ZYKADIA.xml                         polyneuropathy             5082
# 27038  ZYKADIA.xml                         blurred vision             5152
# 27039  ZYKADIA.xml                              photopsia             5168
# 27040  ZYKADIA.xml                 accommodation disorder             5179
# 27042  ZYKADIA.xml                  reduced visual acuity             5218
# 27043  ZYKADIA.xml                  prolonged qt interval             5242
# 27044  ZYKADIA.xml                            bradycardia             5274
# 27045  ZYKADIA.xml                   hemoglobin decreased             5584
# 27047  ZYKADIA.xml                   creatinine increased             5807
# 27048  ZYKADIA.xml                      glucose increased             5870
# 27049  ZYKADIA.xml                    phosphate decreased             5930
# 27050  ZYKADIA.xml                       lipase increased             5992
# 27051  ZYKADIA.xml              bilirubin total increased  605,160,626,069
# 27052  ZYKADIA.xml                               diarrhea              131
# 27053  ZYKADIA.xml                                 nausea              141
# 27054  ZYKADIA.xml                               vomiting              149
# 27055  ZYKADIA.xml                         abdominal pain              161
# 27056  ZYKADIA.xml                         hepatotoxicity              318
# 27057  ZYKADIA.xml                         hepatotoxicity              353
# 27058  ZYKADIA.xml              interstitial lung disease              505
# 27060  ZYKADIA.xml                            pneumonitis              537
# 27063  ZYKADIA.xml                          hyperglycemia             1068
# 27064  ZYKADIA.xml                          hyperglycemia             1102
# 27065  ZYKADIA.xml                            bradycardia             1366
# 27066  ZYKADIA.xml                            bradycardia             1398
# 27067  ZYKADIA.xml                           pancreatitis             1547
# 27068  ZYKADIA.xml                           pancreatitis             1602
# 27071  ZYKADIA.xml                               diarrhea             1975
# 27072  ZYKADIA.xml                                 nausea             1985
# 27073  ZYKADIA.xml                               vomiting             1993
# 27074  ZYKADIA.xml                         abdominal pain             2006
# 27075  ZYKADIA.xml                               diarrhea             2153
# 27076  ZYKADIA.xml                                 nausea             2163
# 27077  ZYKADIA.xml                               vomiting             2171
# 27078  ZYKADIA.xml                         abdominal pain             2184
# 27079  ZYKADIA.xml                         hepatotoxicity             2605
# 27082  ZYKADIA.xml                               jaundice             2894
# 27084  ZYKADIA.xml                        total bilirubin             2966
# 27087  ZYKADIA.xml                            pneumonitis             3666
# 27088  ZYKADIA.xml                            pneumonitis             3734
# 27090  ZYKADIA.xml                            pneumonitis             3826
# 27093  ZYKADIA.xml                            pneumonitis             3884
# 27095  ZYKADIA.xml                            pneumonitis             4013
# 27098  ZYKADIA.xml                           sudden death             4488
# 27103  ZYKADIA.xml                          hyperglycemia             5982
# 27104  ZYKADIA.xml                          hyperglycemia             6065
# 27105  ZYKADIA.xml                          hyperglycemia             6200
# 27106  ZYKADIA.xml                            bradycardia             6912
# 27107  ZYKADIA.xml                      sinus bradycardia             6977
# 27109  ZYKADIA.xml                            bradycardia             7104
# 27110  ZYKADIA.xml                           pancreatitis             8326
# 27117  ZYKADIA.xml                          alt increased       56,695,674
# 27119  ZYKADIA.xml                          ast increased       57,505,755
# 27122  ZYKADIA.xml                     torsade de pointes             4465
#
#          len match_method proposed_meddra_term  \
# 26853      9        exact             10035664
# 26855      8        exact             10012735
# 26856      6        exact             10028813
# 26857     14        exact             10000081
# 26858      8        exact             10047700
# 26859      7        exact             10016256
# 26860      7        exact             10037660
# 26861      8        exact             10003549
# 26862     16        fuzzy             10030124
# 26863     33        fuzzy             10046306
# 26864      9        exact             10035664
# 26865      5        exact             10011224
# 26866      7        exact             10013968
# 26867      4        exact             10037844
# 26868     12        exact             10029410
# 26869      8        exact             10019211
# 26870     18        fuzzy             10061428
# 26871      8        exact             10022437
# 26872     13        exact             10001551
# 26873     13        exact             10003481
# 26874     21        fuzzy             10029368
# 26875     20        fuzzy             10018884
# 26876     19        fuzzy             10035528
# 26878     11        exact             10002198
# 26879     11        exact             10029354
# 26883     14        exact             10019851
# 26885      8        exact             10012735
# 26886      7        exact             10009887
# 26887      8        exact             10012735
# 26888      8        exact             10012735
# 26890     11        exact             10035742
# 26892     22        exact             10022694
# 26893      8        exact             10012735
# 26894     26        fuzzy             10044223
# 26895      3        exact             10044223
# 26897     22        exact             10012455
# 26898      4        exact             10037844
# 26899     17        fuzzy             10037855
# 26900     16        fuzzy             10037844
# 26901     12        fuzzy             10037867
# 26902     19        fuzzy             10037868
# 26903     12        fuzzy             10037876
# 26904     13        fuzzy             10037884
# 26905     16        exact             10064579
# 26906     13        fuzzy             10040831
# 26907     18        fuzzy             10020751
# 26908     11        exact             10002198
# 26909     11        exact             10029354
# 26914      8        exact             10012735
# 26915      7        exact             10009887
# 26916     11        exact             10035742
# 26917     22        exact             10022694
# 26920      8        exact             10012735
# 26921      7        exact             10009887
# 26922     11        exact             10035742
# 26923     22        exact             10022694
# 26925     14        exact             10019851
# 26927      8        exact             10012735
# 26928      7        exact             10009887
# 26930     11        exact             10035742
# 26932     22        exact             10022694
# 26935      8        exact             10012735
# 26936      7        exact             10009887
# 26937     11        exact             10035742
# 26938     22        exact             10022694
# 26940     14        exact             10019851
# 26942      8        exact             10012735
# 26943      7        exact             10009887
# 26945     11        exact             10035742
# 26947     22        exact             10022694
# 26953     25        exact             10059024
# 26954     14        exact             10019851
# 26955     25        fuzzy             10022611
# 26956     11        exact             10035742
# 26958     13        exact             10020635
# 26959     11        exact             10006093
# 26960     12        exact             10033645
# 26961      8        exact             10012735
# 26962      6        exact             10028813
# 26964      8        exact             10047700
# 26965     14        exact             10000081
# 26966      7        exact             10016256
# 26967     18        fuzzy             10061428
# 26968     12        exact             10010774
# 26969     13        fuzzy             10001551
# 26970      6        exact             10028813
# 26971     13        fuzzy             10003481
# 26972      8        exact             10012735
# 26973      8        exact             10047700
# 26974     10        exact             10039906
# 26975      9        exact             10035664
# 26977     11        exact             10035742
# 26978      7        exact             10013968
# 26979     11        exact             10012174
# 26980     13        exact             10020635
# 26981      6        exact             10028813
# 26983      9        exact             10035664
# 26984     19        fuzzy             10038695
# 26986     11        exact             10035742
# 26987     12        exact             10035759
# 26988     18        exact             10017788
# 26989     37        fuzzy             10049438
# 26990     22        exact             10037440
# 26991     17        exact             10007610
# 26992      6        exact             10040047
# 26993      9        exact             10035664
# 26995     11        exact             10035742
# 26996     18        fuzzy             10061428
# 26997     14        exact             10000081
# 26998     14        exact             10000081
# 26999     20        fuzzy             10000087
# 27000     20        exact             10000059
# 27001     21        fuzzy             10053155
# 27002     19        fuzzy             10061318
# 27003      9        exact             10013946
# 27004     31        fuzzy             10017885
# 27005      9        exact             10013950
# 27006      7        exact             10016256
# 27007      7        exact             10016256
# 27008      8        exact             10003549
# 27009      4        exact             10037844
# 27010      4        exact             10037844
# 27011     18        exact             10037868
# 27012     20        exact             10012432
# 27013      8        exact             10012735
# 27014      6        exact             10028813
# 27015      8        exact             10047700
# 27016     14        exact             10000081
# 27017     12        exact             10010774
# 27018     19        fuzzy             10061318
# 27019      7        exact             10016256
# 27020     18        fuzzy             10061428
# 27021      4        exact             10037844
# 27022     25        fuzzy             10022611
# 27023     11        exact             10035742
# 27024     10        exact             10029331
# 27025     11        exact             10033775
# 27026     17        exact             10028372
# 27027     16        fuzzy             10017577
# 27028     21        fuzzy             10029331
# 27029     12        exact             10020937
# 27030     29        fuzzy             10034620
# 27031     11        exact             10013886
# 27032      9        exact             10029223
# 27033     27        fuzzy             10034580
# 27034      9        exact             10021118
# 27035     14        exact             10036105
# 27038     14        exact             10047513
# 27039      9        exact             10034962
# 27040     22        exact             10000389
# 27042     21        fuzzy             10047531
# 27043     21        fuzzy             10014387
# 27044     11        exact             10006093
# 27045     20        fuzzy             10018884
# 27047     20        exact             10005483
# 27048     17        exact             10005557
# 27049     19        fuzzy             10049471
# 27050     16        fuzzy             10024574
# 27051  9,5,9        fuzzy             10005364
# 27052      8        exact             10012735
# 27053      6        exact             10028813
# 27054      8        exact             10047700
# 27055     14        exact             10000081
# 27056     14        exact             10019851
# 27057     14        exact             10019851
# 27058     25        fuzzy             10022611
# 27060     11        exact             10035742
# 27063     13        exact             10020635
# 27064     13        exact             10020635
# 27065     11        exact             10006093
# 27066     11        exact             10006093
# 27067     12        exact             10033645
# 27068     12        exact             10033645
# 27071      8        exact             10012735
# 27072      6        exact             10028813
# 27073      8        exact             10047700
# 27074     14        exact             10000081
# 27075      8        exact             10012735
# 27076      6        exact             10028813
# 27077      8        exact             10047700
# 27078     14        exact             10000081
# 27079     14        exact             10019851
# 27082      8        exact             10023126
# 27084     15        fuzzy             10005362
# 27087     11        exact             10035742
# 27088     11        exact             10035742
# 27090     11        exact             10035742
# 27093     11        exact             10035742
# 27095     11        exact             10035742
# 27098     12        fuzzy             10042434
# 27103     13        exact             10020635
# 27104     13        exact             10020635
# 27105     13        exact             10020635
# 27106     11        exact             10006093
# 27107     17        fuzzy             10040741
# 27109     11        exact             10006093
# 27110     12        exact             10033645
# 27117    3,9        exact             10001551
# 27119    3,9        exact             10003481
# 27122     18        fuzzy             10044066
#
#                      proposed_meddra_strings
# 26853                              pneumonia
# 26855                              diarrhoea
# 26856                                 nausea
# 26857                         abdominal pain
# 26858                               vomiting
# 26859                                fatigue
# 26860                                pyrexia
# 26861                               asthenia
# 26862                      oedema peripheral
# 26863      infection respiratory tract upper
# 26864                              pneumonia
# 26865                                  cough
# 26866                               dyspnoea
# 26867                                   rash
# 26868                           night sweats
# 26869                               headache
# 26870                     appetite decreased
# 26871                               insomnia
# 26872     alanine aminotransferase increased
# 26873   aminotransferase aspartate increased
# 26874             count increased neutrophil
# 26875                  decreased haemoglobin
# 26876               count decreased platelet
# 26878                  anaphylactic reaction
# 26879                            neutropenia
# 26883                         hepatotoxicity
# 26885                              diarrhoea
# 26886                                colitis
# 26887                              diarrhoea
# 26888                              diarrhoea
# 26890                            pneumonitis
# 26892                 intestinal perforation
# 26893                              diarrhoea
# 26894             epidermal necrolysis toxic
# 26895             epidermal necrolysis toxic
# 26897                 dermatitis exfoliative
# 26898                                   rash
# 26899                      erythematous rash
# 26900                                   rash
# 26901                           macular rash
# 26902                    maculo-papular rash
# 26903                           papular rash
# 26904                          pruritic rash
# 26905                       exfoliative rash
# 26906                          disorder skin
# 26907                       hypersensitivity
# 26908                  anaphylactic reaction
# 26909                            neutropenia
# 26914                              diarrhoea
# 26915                                colitis
# 26916                            pneumonitis
# 26917                 intestinal perforation
# 26920                              diarrhoea
# 26921                                colitis
# 26922                            pneumonitis
# 26923                 intestinal perforation
# 26925                         hepatotoxicity
# 26927                              diarrhoea
# 26928                                colitis
# 26930                            pneumonitis
# 26932                 intestinal perforation
# 26935                              diarrhoea
# 26936                                colitis
# 26937                            pneumonitis
# 26938                 intestinal perforation
# 26940                         hepatotoxicity
# 26942                              diarrhoea
# 26943                                colitis
# 26945                            pneumonitis
# 26947                 intestinal perforation
# 26953              gastrointestinal toxicity
# 26954                         hepatotoxicity
# 26955              disease interstitial lung
# 26956                            pneumonitis
# 26958                         hyperglycaemia
# 26959                            bradycardia
# 26960                           pancreatitis
# 26961                              diarrhoea
# 26962                                 nausea
# 26964                               vomiting
# 26965                         abdominal pain
# 26966                                fatigue
# 26967                     appetite decreased
# 26968                           constipation
# 26969     alanine aminotransferase increased
# 26970                                 nausea
# 26971   aminotransferase aspartate increased
# 26972                              diarrhoea
# 26973                               vomiting
# 26974                                seizure
# 26975                              pneumonia
# 26977                            pneumonitis
# 26978                               dyspnoea
# 26979                            dehydration
# 26980                         hyperglycaemia
# 26981                                 nausea
# 26983                              pneumonia
# 26984                    failure respiratory
# 26986                            pneumonitis
# 26987                           pneumothorax
# 26988                    gastric haemorrhage
# 26989  deterioration general health physical
# 26990                 pulmonary tuberculosis
# 26991                      cardiac tamponade
# 26992                                 sepsis
# 26993                              pneumonia
# 26995                            pneumonitis
# 26996                     appetite decreased
# 26997                         abdominal pain
# 26998                         abdominal pain
# 26999                   abdominal pain upper
# 27000                   abdominal discomfort
# 27001                  discomfort epigastric
# 27002                   disorder oesophageal
# 27003                              dyspepsia
# 27004       disease gastrooesophageal reflux
# 27005                              dysphagia
# 27006                                fatigue
# 27007                                fatigue
# 27008                               asthenia
# 27009                                   rash
# 27010                                   rash
# 27011                    maculo-papular rash
# 27012                   acneiform dermatitis
# 27013                              diarrhoea
# 27014                                 nausea
# 27015                               vomiting
# 27016                         abdominal pain
# 27017                           constipation
# 27018                   disorder oesophageal
# 27019                                fatigue
# 27020                     appetite decreased
# 27021                                   rash
# 27022              disease interstitial lung
# 27023                            pneumonitis
# 27024                  neuropathy peripheral
# 27025                           paraesthesia
# 27026                      muscular weakness
# 27027                       disturbance gait
# 27028                  neuropathy peripheral
# 27029                          hypoaesthesia
# 27030          neuropathy peripheral sensory
# 27031                           dysaesthesia
# 27032                              neuralgia
# 27033            motor neuropathy peripheral
# 27034                              hypotonia
# 27035                         polyneuropathy
# 27038                         blurred vision
# 27039                              photopsia
# 27040                 accommodation disorder
# 27042                  acuity reduced visual
# 27043         electrocardiogram prolonged qt
# 27044                            bradycardia
# 27045                  decreased haemoglobin
# 27047             blood creatinine increased
# 27048                blood glucose increased
# 27049             blood decreased phosphorus
# 27050                       increased lipase
# 27051              bilirubin blood increased
# 27052                              diarrhoea
# 27053                                 nausea
# 27054                               vomiting
# 27055                         abdominal pain
# 27056                         hepatotoxicity
# 27057                         hepatotoxicity
# 27058              disease interstitial lung
# 27060                            pneumonitis
# 27063                         hyperglycaemia
# 27064                         hyperglycaemia
# 27065                            bradycardia
# 27066                            bradycardia
# 27067                           pancreatitis
# 27068                           pancreatitis
# 27071                              diarrhoea
# 27072                                 nausea
# 27073                               vomiting
# 27074                         abdominal pain
# 27075                              diarrhoea
# 27076                                 nausea
# 27077                               vomiting
# 27078                         abdominal pain
# 27079                         hepatotoxicity
# 27082                               jaundice
# 27084                        bilirubin blood
# 27087                            pneumonitis
# 27088                            pneumonitis
# 27090                            pneumonitis
# 27093                            pneumonitis
# 27095                            pneumonitis
# 27098                           death sudden
# 27103                         hyperglycaemia
# 27104                         hyperglycaemia
# 27105                         hyperglycaemia
# 27106                            bradycardia
# 27107                      bradycardia sinus
# 27109                            bradycardia
# 27110                           pancreatitis
# 27117     alanine aminotransferase increased
# 27119   aminotransferase aspartate increased
# 27122                     de pointes torsade

# %%
# and save
Deepcadrme_guess_terms.to_csv("../data/deepcadrme_guess_terms_meddramatch.csv")
