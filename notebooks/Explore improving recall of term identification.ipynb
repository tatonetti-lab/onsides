# %%
import os
import csv

import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Exploring the problem
#
# Let's begin by looking a little more closely at the issue. Our first pass at identifying adverse event terms is to look through the labels for exact string matches to the MedDRA adverse event terminology terms. This misses many of the terms that were identified manually through a review of 200 notes (by the amazing TAC team).
#
# We start by looking at the manual annotations provided by the TAC team.
#
# NOTE: For both the manual annotations, the PT is also listed as an LLT so that we only need look at the LLT column.

# %%
manual_annotations_file = '../data/200_manual_annotations_csv/FinalReferenceStandard200Labels_comma.csv'

manual_df = pd.read_csv(manual_annotations_file)
manual_df['drug'] = manual_df['Drug Name'].str.lower()

matching_string_sorted = list()
for index, row in manual_df.iterrows():
    matching_string_sorted.append(' '.join(sorted(str(row['Matching String']).split())))
manual_df['matching_string_sorted'] = matching_string_sorted

print(manual_df.shape)
manual_df.head()
# Out:
# (14487, 16)
#    Index                               Drug ID Drug Name Section LOINC  \
# 0      1  00a8921e-46a6-4df1-a744-9e532b6fb06f   NUCYNTA       34084-4
# 1      2  00a8921e-46a6-4df1-a744-9e532b6fb06f   NUCYNTA       34084-4
# 2      3  00a8921e-46a6-4df1-a744-9e532b6fb06f   NUCYNTA       34084-4
# 3      4  00a8921e-46a6-4df1-a744-9e532b6fb06f   NUCYNTA       34084-4
# 4      5  00a8921e-46a6-4df1-a744-9e532b6fb06f   NUCYNTA       34084-4
#
#   Section Display Name                           MedDRA PT       PT ID  \
# 0    ADVERSE REACTIONS                Abdominal discomfort  10000059.0
# 1    ADVERSE REACTIONS                     Abnormal dreams  10000125.0
# 2    ADVERSE REACTIONS                           Agitation  10001497.0
# 3    ADVERSE REACTIONS  Alanine aminotransferase increased  10001551.0
# 4    ADVERSE REACTIONS                 Alcohol interaction  10001597.0
#
#                            MedDRA LLT      LLT ID  \
# 0                Abdominal discomfort  10000059.0
# 1                     Abnormal dreams  10000125.0
# 2                           Agitation  10001497.0
# 3  Alanine aminotransferase increased  10001551.0
# 4            Interaction with alcohol  10022527.0
#
#                       Matching String  UMLS CUI  \
# 0                abdominal discomfort  C0232487
# 1                     abnormal dreams  C0234458
# 2                           agitation  C0085631
# 3  alanine aminotransferase increased  C0151905
# 4            interaction with alcohol  C0853206
#
#                         UMLS PrefName Flag 1 Flag 2     drug  \
# 0                Abdominal discomfort    NaN    NaN  nucynta
# 1                      Dream disorder    NaN    NaN  nucynta
# 2                           Agitation    NaN    NaN  nucynta
# 3  Alanine aminotransferase increased    NaN    NaN  nucynta
# 4                 Alcohol interaction    NaN    NaN  nucynta
#
#                matching_string_sorted
# 0                abdominal discomfort
# 1                     abnormal dreams
# 2                           agitation
# 3  alanine aminotransferase increased
# 4            alcohol interaction with

# %%
# how many of the terms match either the LLT they were mapped to?
total_n = manual_df.shape[0]
exact_n = manual_df[manual_df['Matching String'].str.lower()==manual_df['MedDRA LLT'].str.lower()].shape[0]

exact_n, total_n, exact_n/total_n
# Out:
# (10188, 14487, 0.7032511907227169)

# %%
manual_df[manual_df['Matching String'].str.lower()!=manual_df['MedDRA LLT'].str.lower()]
# Out:
#        Index                               Drug ID Drug Name Section LOINC  \
# 12        13  00a8921e-46a6-4df1-a744-9e532b6fb06f   NUCYNTA       34084-4
# 25        26  00a8921e-46a6-4df1-a744-9e532b6fb06f   NUCYNTA       34084-4
# 37        38  00a8921e-46a6-4df1-a744-9e532b6fb06f   NUCYNTA       34084-4
# 46        47  00a8921e-46a6-4df1-a744-9e532b6fb06f   NUCYNTA       34084-4
# 52        53  00a8921e-46a6-4df1-a744-9e532b6fb06f   NUCYNTA       34084-4
# ...      ...                                   ...       ...           ...
# 14474  14475  fff5d805-4ffd-4e8e-8e63-6f129697563e   ZYKADIA       43685-7
# 14476  14477  fff5d805-4ffd-4e8e-8e63-6f129697563e   ZYKADIA       43685-7
# 14477  14478  fff5d805-4ffd-4e8e-8e63-6f129697563e   ZYKADIA       43685-7
# 14484  14485  fff5d805-4ffd-4e8e-8e63-6f129697563e   ZYKADIA       43685-7
# 14485  14486  fff5d805-4ffd-4e8e-8e63-6f129697563e   ZYKADIA       43685-7
#
#            Section Display Name                        MedDRA PT       PT ID  \
# 12            ADVERSE REACTIONS      Chronic respiratory disease  10061768.0
# 25            ADVERSE REACTIONS                  Drug dependence  10013663.0
# 37            ADVERSE REACTIONS        Gastrointestinal disorder  10017944.0
# 46            ADVERSE REACTIONS                      Hypotension  10021097.0
# 52            ADVERSE REACTIONS  Muscle contractions involuntary  10028293.0
# ...                         ...                              ...         ...
# 14474  WARNINGS AND PRECAUTIONS        Interstitial lung disease  10022611.0
# 14476  WARNINGS AND PRECAUTIONS                 Lipase increased  10024574.0
# 14477  WARNINGS AND PRECAUTIONS  Maternal drugs affecting foetus  10026923.0
# 14484  WARNINGS AND PRECAUTIONS          Transaminases increased  10054889.0
# 14485  WARNINGS AND PRECAUTIONS      Ventricular tachyarrhythmia  10065341.0
#
#                                MedDRA LLT      LLT ID  \
# 12            Chronic respiratory disease  10061768.0
# 25                   Dependence addictive  10012336.0
# 37           Gastrointestinal symptom NOS  10018011.0
# 46                            Hypotensive  10021107.0
# 52        Muscle contractions involuntary  10028293.0
# ...                                   ...         ...
# 14474           Interstitial lung disease  10022611.0
# 14476                    Lipase increased  10024574.0
# 14477  Drug toxicity NEC affecting foetus  10013750.0
# 14484             Transaminases increased  10054889.0
# 14485         Ventricular tachyarrhythmia  10065341.0
#
#                        Matching String  UMLS CUI  \
# 12           chronic pulmonary disease  C0264220
# 25                           addiction  C0085281
# 37            gastrointestinal effects  C0426576
# 46                 hypotensive effects  C0857353
# 52     involuntary muscle contractions  C0235086
# ...                                ...       ...
# 14474                              ild  C0206062
# 14476             elevations of lipase  C1963823
# 14477             embryofetal toxicity  C0270009
# 14484           elevated transaminases  C0438717
# 14485     ventricular tachyarrhythmias  C0042514
#
#                                            UMLS PrefName Flag 1 Flag 2  \
# 12                 Chronic disease of respiratory system    NaN    NaN
# 25                                    Addictive Behavior    NaN    NaN
# 37                              Gastrointestinal symptom    NaN    NaN
# 46                                           Hypotensive    NaN    NaN
# 52                        Involuntary muscle contraction    NaN    NaN
# ...                                                  ...    ...    ...
# 14474                                      Lung Diseases    NaN    NaN
# 14476                                    Hyperlipasaemia    NaN    NaN
# 14477  Fetal or neonatal effect of toxic substance tr...    NaN    NaN
# 14484                            Transaminases increased    NaN    NaN
# 14485                                        Tachycardia    NaN    NaN
#
#           drug           matching_string_sorted
# 12     nucynta        chronic disease pulmonary
# 25     nucynta                        addiction
# 37     nucynta         effects gastrointestinal
# 46     nucynta              effects hypotensive
# 52     nucynta  contractions involuntary muscle
# ...        ...                              ...
# 14474  zykadia                              ild
# 14476  zykadia             elevations lipase of
# 14477  zykadia             embryofetal toxicity
# 14484  zykadia           elevated transaminases
# 14485  zykadia     tachyarrhythmias ventricular
#
# [4299 rows x 16 columns]

# %% [markdown]
# Let's compare that to if we use the MedDRA vocabulary itself and relook for the terms. This should produce about the same result as the quick calculation above.

# %%
# load the meddra dictionary
meddra_23p1_file = '../data/meddra_pt_llt_map_omop_v23.1.csv'
meddra_df = pd.read_csv(meddra_23p1_file)
meddra_df.head()
# Out:
#    pt_concept_id    pt_concept_name  pt_meddra_id  llt_concept_id  \
# 0         788094  Defiant behaviour      10077244          788741
# 1         788095        Proctectomy      10077252        37585820
# 2         788095        Proctectomy      10077252        43010901
# 3         788095        Proctectomy      10077252        37585816
# 4         788095        Proctectomy      10077252        45887267
#
#                         llt_concept_name  llt_meddra_id
# 0                       Defiant behavior       10077245
# 1              Total mesorectal excision       10069130
# 2               Lower anterior resection       10083500
# 3  Abdomino-perineal resection of rectum       10000108
# 4             Abdominoperineal resection       10075500

# %%
# build a dictionary from llt to pt
llt2pt = dict()
for index, row in meddra_df.iterrows():
    llt2pt[row['llt_meddra_id']] = row['pt_meddra_id']
    llt2pt[row['pt_meddra_id']] = row['pt_meddra_id']

# %%
meddra_terms = set(meddra_df['llt_concept_name'].str.lower())
meddra_terms |= set(meddra_df['pt_concept_name'].str.lower())
len(meddra_terms)
# Out:
# 62571

# %%
meddra_exact_n = 0
for index, row in manual_df.iterrows():
    if type(row['Matching String']) != str:
        continue
    
    if row['Matching String'].lower() in meddra_terms:
        meddra_exact_n += 1

meddra_exact_n, total_n, meddra_exact_n/total_n
# Out:
# (10051, 14487, 0.6937944363912473)

# %% [markdown]
# ## Non-exact Matches Review
#
# Cindy Chen did excellent work to review many of the ones that did not match and figure out the reason. Terms in different order and wording differences were found to be the largest two categories.

# %%
unscored_file = '../data/unscored_terms_with_notes.csv'
unscored_df = pd.read_csv(unscored_file)
unscored_df['drug'] = unscored_df['drug'].str.lower()

unscored_df['pt_id'] = unscored_df['llt_id'].astype(str).transform(lambda x: int(llt2pt.get(int(x), -1)))

unscored_df['drug,pt_id'] = list(zip(unscored_df['drug'], unscored_df['pt_id']))

unscored_df.head()
# Out:
#       drug                          meddra_term            term in label  \
# 0  actemra  absolute neutrophil count decreased  decreases in neutrophil
# 1  actemra                  arthritis bacterial      bacterial arthritis
# 2  actemra                        ast increased                      NaN
# 3  actemra            bilirubin total increased                      NaN
# 4  actemra          cholesterol total increased                      NaN
#
#                    Problem Why was it not annotated?     class  Pred0  Pred1  \
# 0  Term in different order                       NaN  is_event      0      0
# 1  Term in different order  terms in different order  is_event      0      0
# 2                      NaN                       NaN  is_event      0      0
# 3                      NaN                       NaN  is_event      0      0
# 4                      NaN                       NaN  is_event      0      0
#
#        scored  split  Property section    llt_id other notes     pt_id  \
# 0  not_scored  train     20859      AR  10059234         NaN  10029366
# 1  not_scored  train     20310      AR  10053555         NaN  10053555
# 2  not_scored  train     20069      AR  10003544         NaN  10003481
# 3  not_scored  train     20968      AR  10056806         NaN  10005364
# 4  not_scored  train     20568      AR  10008671         NaN  10005425
#
#             drug,pt_id
# 0  (actemra, 10029366)
# 1  (actemra, 10053555)
# 2  (actemra, 10003481)
# 3  (actemra, 10005364)
# 4  (actemra, 10005425)

# %%
unscored_df.groupby('Problem').count()['drug']
# Out:
# Problem
# Abbreviations                                                       3
# Abbreviations, Extra word in meddra                                 1
# Abbreviations, Parentheses, Term in different order                 3
# Abbreviations, Term in different order                              1
# Abbreviations, Term in different order, Wording Differences         2
# Abbreviations, Word insertion and lists                             1
# Abbreviations, Word insertion and lists, Wording Differences        1
# Abbreviations, Wording Differences                                  2
# Extra word in meddra                                               14
# Extra word in meddra, Hyphens                                       1
# Extra word in meddra, Spelling                                      1
# Extra word in meddra, Term in different order                       1
# Extra word in meddra, Wording Differences                           2
# Hyphens                                                            18
# Hyphens, Parentheses                                                1
# Hyphens, Word insertion and lists                                  13
# Hyphens, Wording Differences                                        1
# Parentheses                                                         6
# Parentheses, Term in different order                                7
# Parentheses, Term in different order, Word insertion and lists      2
# Parentheses, Word insertion and lists                               7
# Parentheses, Wording Differences                                    2
# Spelling                                                           25
# Spelling, Term in different order                                   4
# Spelling, Word insertion and lists                                  2
# Spelling, nos                                                       1
# Term in different order                                           112
# Term in different order, Word insertion and lists                  11
# Term in different order, Wording Differences                       34
# Word insertion and lists                                           78
# Word insertion and lists, Wording Differences                       8
# Wording Differences                                               183
# Wording Differences, it's complicated                               6
# Wording Differences, nos                                            4
# it's complicated                                                    1
# nos                                                                 1
# Name: drug, dtype: int64

# %%
unscored_df[unscored_df['Problem'] == 'Wording Differences']
# Out:
#          drug                        meddra_term  \
# 5     ACTEMRA                              death
# 13    ACTEMRA                 neoplasm malignant
# 20   ADCETRIS                              death
# 21   ADCETRIS                      drug toxicity
# 22   ADCETRIS                     hematotoxicity
# ..        ...                                ...
# 607  INVOKANA                upper limb fracture
# 608   ISTODAX        arrhythmia supraventricular
# 609   ISTODAX        ecg nonspecific st-t change
# 610   ISTODAX           electrocardiogram change
# 611   ISTODAX  electrocardiogram t wave abnormal
#
#                                          term in label              Problem  \
# 5                                                  NaN  Wording Differences
# 13   Malignancies During the 24 week, controlled pe...  Wording Differences
# 20                                                 NaN  Wording Differences
# 21   The most common adverse reactions occurring in...  Wording Differences
# 22                                                 NaN  Wording Differences
# ..                                                 ...                  ...
# 607  Fractures were observed as early as 12 weeks a...  Wording Differences
# 608                        supraventricular arrhythmia  Wording Differences
# 609                Electrocardiogram ST-T wave changes  Wording Differences
# 610                Electrocardiogram ST-T wave changes  Wording Differences
# 611                Electrocardiogram ST-T wave changes  Wording Differences
#
#                              Why was it not annotated?     class  Pred0  \
# 5                                  not mentioned in AR  is_event      0
# 13                  "malignancies" instead of neoplasm  is_event      0
# 20                                 not mentioned in AR  is_event      0
# 21                            not explicitly mentioned  is_event      0
# 22   not explicitly mentioned� what does 'hematotox...  is_event      0
# ..                                                 ...       ...    ...
# 607                                                NaN  is_event      0
# 608                                                NaN  is_event      0
# 609                                                NaN  is_event      0
# 610                                                NaN  is_event      0
# 611                                                NaN  is_event      0
#
#      Pred1      scored  split  Property section    llt_id other notes
# 5        0  not_scored  train     20608      AR  10011906         NaN
# 13       0  not_scored  train     20578      AR  10028997         NaN
# 20       0  not_scored  train     21164      AR  10011906         NaN
# 21       0  not_scored  train     21116      AR  10013746         NaN
# 22       0  not_scored  train     20749      AR  10061196         NaN
# ..     ...         ...    ...       ...     ...       ...         ...
# 607      0  not_scored   test      2128      AR  10061394         NaN
# 608      0  not_scored  train     20192      AR  10003130         NaN
# 609      0  not_scored  train     20678      AR  10057502         NaN
# 610      0  not_scored  train     21149      AR  10061116         NaN
# 611      0  not_scored  train     20097      AR  10050380         NaN
#
# [183 rows x 14 columns]

# %% [markdown]
# ## DeepCADRME
#
# DeepCADRME is a method for identifying adverse event terms from the labels when they are not continuous. It should help to address the primary two categories. We (Cindy) ran DeepCADRME on the 199 of the 200 labels from TAC (one label wasn't available for some reason). Here we explore how many of the missing ~4k annotations are recovered using this method.

# %%
deepcadrme_file = '../data/deepcadrme_guess_terms_meddramatch.csv'
deepcadrme_df = pd.read_csv(deepcadrme_file)

deepcadrme_df['drug'] = deepcadrme_df['file'].str.strip('.xml')
deepcadrme_df['drug'] = deepcadrme_df['drug'].str.lower()

deepcadrme_df.head()
# Out:
#    Unnamed: 0         file                                term start len  \
# 0           0  ACTEMRA.xml  upper respiratory tract infections   410  34
# 1           1  ACTEMRA.xml                     nasopharyngitis   446  15
# 2           2  ACTEMRA.xml                            headache   463   8
# 3           3  ACTEMRA.xml                        hypertension   473  12
# 4           4  ACTEMRA.xml                       increased alt   487  13
#
#   match_method  proposed_meddra_term             proposed_meddra_strings  \
# 0        fuzzy              10046306   infection respiratory tract upper
# 1        exact              10028810                     nasopharyngitis
# 2        exact              10019211                            headache
# 3        exact              10020772                        hypertension
# 4        fuzzy              10001551  alanine aminotransferase increased
#
#       drug
# 0  actemra
# 1  actemra
# 2  actemra
# 3  actemra
# 4  actemra

# %%
len(set(manual_df['drug'])), len(set(deepcadrme_df['drug'])), len(set(manual_df['drug']) & set(deepcadrme_df['drug']))
# Out:
# (200, 199, 199)

# %%
nonexact_manual_df = manual_df[manual_df['Matching String'].str.lower()!=manual_df['MedDRA LLT'].str.lower()]
nonexact_manual_df = nonexact_manual_df[~nonexact_manual_df['PT ID'].isnull()]
nonexact_manual_df.shape
# Out:
# (4251, 16)

# %%
# Map to PTs and turn into a set
nonexact_annots = set(zip(nonexact_manual_df['drug'], nonexact_manual_df['PT ID'].astype(int)))
len(nonexact_annots)
# Out:
# 3200

# %%
deepcadrme_annots = set(zip(deepcadrme_df['drug'], deepcadrme_df['proposed_meddra_term']))
len(deepcadrme_annots)
# Out:
# 9399

# %%
# Number and proportion of missing annotations recovered by using DeepCADRME
len(nonexact_annots & deepcadrme_annots), len(nonexact_annots & deepcadrme_annots)/len(nonexact_annots)
# Out:
# (1278, 0.399375)

# %%
unscored_annots = set(zip(unscored_df['drug'], unscored_df['pt_id']))

len(unscored_annots), len(unscored_annots & deepcadrme_annots)
# Out:
# (1447, 513)

# %%
unscored_df[unscored_df['drug,pt_id'].isin(deepcadrme_annots)].groupby('Problem').count()['drug']
# Out:
# Problem
# Abbreviations                                                      2
# Abbreviations, Extra word in meddra                                1
# Abbreviations, Term in different order                             1
# Extra word in meddra                                               7
# Extra word in meddra, Spelling                                     1
# Extra word in meddra, Term in different order                      1
# Extra word in meddra, Wording Differences                          1
# Hyphens                                                           13
# Hyphens, Parentheses                                               1
# Hyphens, Word insertion and lists                                  1
# Parentheses                                                        6
# Parentheses, Term in different order                               5
# Parentheses, Term in different order, Word insertion and lists     2
# Parentheses, Word insertion and lists                              1
# Spelling                                                          12
# Spelling, Term in different order                                  2
# Spelling, Word insertion and lists                                 1
# Term in different order                                           82
# Term in different order, Word insertion and lists                  2
# Term in different order, Wording Differences                       6
# Word insertion and lists                                          24
# Wording Differences                                               42
# Wording Differences, it's complicated                              1
# Wording Differences, nos                                           1
# nos                                                                1
# Name: drug, dtype: int64

# %% [markdown]
# ## N-gram Resort
#
# Explore how many of the terms could be identified by looking at different permutations of the words in an adverse event term.

# %%
meddra_terms_sorted = set(map(lambda x: ' '.join(sorted(x.split())), meddra_terms))

# %%
meddra_exactsorted_n = manual_df[manual_df['matching_string_sorted'].isin(meddra_terms_sorted)].shape[0]

meddra_exactsorted_n, total_n, meddra_exactsorted_n/total_n
# Out:
# (10378, 14487, 0.7163663974597916)

# %%
resort_matches = nonexact_manual_df[nonexact_manual_df['matching_string_sorted'].isin(meddra_terms_sorted)].shape[0]

resort_matches, nonexact_manual_df.shape[0]
# Out:
# (417, 4251)

# %%
resort_matches_df = nonexact_manual_df[nonexact_manual_df['matching_string_sorted'].isin(meddra_terms_sorted)]
resort_annots = set(zip(resort_matches_df['drug'], resort_matches_df['PT ID']))
len(resort_annots)
# Out:
# 380

# %%
len(resort_annots & deepcadrme_annots)
# Out:
# 298
